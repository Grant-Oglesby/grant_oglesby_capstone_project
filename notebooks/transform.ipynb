# %% [markdown]
# # Data Transformation Analysis

# %%
# Import required packages and setup function for df read
import pandas as pd

# Set pandas to display up to rows
pd.options.display.max_rows = 100

def import_data(file_path):
    df = pd.read_csv(file_path)
    return df

# %%
# Function to determine null values as percentage of total values in each column
def null_percentage(df):
    return df.isnull().mean() * 100

# Function to determine 0.0 values as percentage of total values in each column
def count_zeros(df):
    return (df == 0).mean() * 100

# Function to identify duplicate rows
def duplicate_rows(df):
    return df[df.duplicated()]

# Function to confirm data type of each column
def column_types(df):
    return df.dtypes

# %% [markdown]
# ## Dataset 1: Global CO2 Emissions

# %%
df_co2 = import_data('../data/extract/data0.csv')

df_co2.drop(columns=['Unnamed: 0'], inplace=True, errors='ignore')
df_co2
# Out:
#            country  year iso_code   population             gdp  cement_co2  \
# 0      Afghanistan  1750      AFG  2802560.000             NaN       0.000
# 1      Afghanistan  1751      AFG          NaN             NaN       0.000
# 2      Afghanistan  1752      AFG          NaN             NaN       0.000
# 3      Afghanistan  1753      AFG          NaN             NaN       0.000
# 4      Afghanistan  1754      AFG          NaN             NaN       0.000
# ...            ...   ...      ...          ...             ...         ...
# 50186     Zimbabwe  2019      ZWE 15271377.000 25146417152.000       0.473
# 50187     Zimbabwe  2020      ZWE 15526888.000 23178706944.000       0.496
# 50188     Zimbabwe  2021      ZWE 15797220.000 25140088832.000       0.531
# 50189     Zimbabwe  2022      ZWE 16069061.000 25901586432.000       0.531
# 50190     Zimbabwe  2023      ZWE 16340829.000             NaN       0.531
#
#        cement_co2_per_capita    co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                      0.000    NaN             NaN              NaN  ...
# 1                        NaN    NaN             NaN              NaN  ...
# 2                        NaN    NaN             NaN              NaN  ...
# 3                        NaN    NaN             NaN              NaN  ...
# 4                        NaN    NaN             NaN              NaN  ...
# ...                      ...    ...             ...              ...  ...
# 50186                  0.031 10.263          -0.942           -8.411  ...
# 50187                  0.032  8.495          -1.768          -17.231  ...
# 50188                  0.034 10.204           1.709           20.120  ...
# 50189                  0.033 10.425           0.221            2.169  ...
# 50190                  0.032 11.164           0.739            7.090  ...
#
#        share_global_other_co2  share_of_temperature_change_from_ghg  \
# 0                         NaN                                   NaN
# 1                         NaN                                   NaN
# 2                         NaN                                   NaN
# 3                         NaN                                   NaN
# 4                         NaN                                   NaN
# ...                       ...                                   ...
# 50186                     NaN                                 0.106
# 50187                     NaN                                 0.105
# 50188                     NaN                                 0.104
# 50189                     NaN                                 0.103
# 50190                     NaN                                 0.102
#
#        temperature_change_from_ch4  temperature_change_from_co2  \
# 0                              NaN                          NaN
# 1                              NaN                          NaN
# 2                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 50186                        0.001                        0.001
# 50187                        0.001                        0.001
# 50188                        0.001                        0.001
# 50189                        0.001                        0.001
# 50190                        0.001                        0.001
#
#        temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 0                              NaN                          NaN        NaN
# 1                              NaN                          NaN        NaN
# 2                              NaN                          NaN        NaN
# 3                              NaN                          NaN        NaN
# 4                              NaN                          NaN        NaN
# ...                            ...                          ...        ...
# 50186                        0.002                        0.000     34.348
# 50187                        0.002                        0.000     31.323
# 50188                        0.002                        0.000     33.549
# 50189                        0.002                        0.000     33.772
# 50190                        0.002                        0.000     33.955
#
#        total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 0                           NaN        NaN              NaN
# 1                           NaN        NaN              NaN
# 2                           NaN        NaN              NaN
# 3                           NaN        NaN              NaN
# 4                           NaN        NaN              NaN
# ...                         ...        ...              ...
# 50186                    17.531     -0.027           -0.261
# 50187                    15.775      0.612            7.209
# 50188                    17.599      0.539            5.280
# 50189                    17.910      0.315            3.018
# 50190                    18.608        NaN              NaN
#
# [50191 rows x 79 columns]

# %%
countries = df_co2['country'].unique()
countries_count = len(countries)
countries_count
# Out:
# 255

# %% [markdown]
# 255 unique countries counted within dataset.

# %%
df_co2 = df_co2.groupby(['country', 'year']).agg('sum').reset_index()
df_co2
# Out:
#            country  year iso_code   population             gdp  cement_co2  \
# 0      Afghanistan  1750      AFG  2802560.000           0.000       0.000
# 1      Afghanistan  1751      AFG        0.000           0.000       0.000
# 2      Afghanistan  1752      AFG        0.000           0.000       0.000
# 3      Afghanistan  1753      AFG        0.000           0.000       0.000
# 4      Afghanistan  1754      AFG        0.000           0.000       0.000
# ...            ...   ...      ...          ...             ...         ...
# 50186     Zimbabwe  2019      ZWE 15271377.000 25146417152.000       0.473
# 50187     Zimbabwe  2020      ZWE 15526888.000 23178706944.000       0.496
# 50188     Zimbabwe  2021      ZWE 15797220.000 25140088832.000       0.531
# 50189     Zimbabwe  2022      ZWE 16069061.000 25901586432.000       0.531
# 50190     Zimbabwe  2023      ZWE 16340829.000           0.000       0.531
#
#        cement_co2_per_capita    co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                      0.000  0.000           0.000            0.000  ...
# 1                      0.000  0.000           0.000            0.000  ...
# 2                      0.000  0.000           0.000            0.000  ...
# 3                      0.000  0.000           0.000            0.000  ...
# 4                      0.000  0.000           0.000            0.000  ...
# ...                      ...    ...             ...              ...  ...
# 50186                  0.031 10.263          -0.942           -8.411  ...
# 50187                  0.032  8.495          -1.768          -17.231  ...
# 50188                  0.034 10.204           1.709           20.120  ...
# 50189                  0.033 10.425           0.221            2.169  ...
# 50190                  0.032 11.164           0.739            7.090  ...
#
#        share_global_other_co2  share_of_temperature_change_from_ghg  \
# 0                       0.000                                 0.000
# 1                       0.000                                 0.000
# 2                       0.000                                 0.000
# 3                       0.000                                 0.000
# 4                       0.000                                 0.000
# ...                       ...                                   ...
# 50186                   0.000                                 0.106
# 50187                   0.000                                 0.105
# 50188                   0.000                                 0.104
# 50189                   0.000                                 0.103
# 50190                   0.000                                 0.102
#
#        temperature_change_from_ch4  temperature_change_from_co2  \
# 0                            0.000                        0.000
# 1                            0.000                        0.000
# 2                            0.000                        0.000
# 3                            0.000                        0.000
# 4                            0.000                        0.000
# ...                            ...                          ...
# 50186                        0.001                        0.001
# 50187                        0.001                        0.001
# 50188                        0.001                        0.001
# 50189                        0.001                        0.001
# 50190                        0.001                        0.001
#
#        temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 0                            0.000                        0.000      0.000
# 1                            0.000                        0.000      0.000
# 2                            0.000                        0.000      0.000
# 3                            0.000                        0.000      0.000
# 4                            0.000                        0.000      0.000
# ...                            ...                          ...        ...
# 50186                        0.002                        0.000     34.348
# 50187                        0.002                        0.000     31.323
# 50188                        0.002                        0.000     33.549
# 50189                        0.002                        0.000     33.772
# 50190                        0.002                        0.000     33.955
#
#        total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 0                         0.000      0.000            0.000
# 1                         0.000      0.000            0.000
# 2                         0.000      0.000            0.000
# 3                         0.000      0.000            0.000
# 4                         0.000      0.000            0.000
# ...                         ...        ...              ...
# 50186                    17.531     -0.027           -0.261
# 50187                    15.775      0.612            7.209
# 50188                    17.599      0.539            5.280
# 50189                    17.910      0.315            3.018
# 50190                    18.608      0.000            0.000
#
# [50191 rows x 79 columns]

# %%
# Count of how many times each year is covered
years_covered = df_co2['year'].value_counts()
years_covered
# Out:
# year
# 2023    255
# 2006    255
# 2005    255
# 2004    255
# 2003    255
#        ...
# 1779     58
# 1780     58
# 1781     58
# 1782     58
# 1750     58
# Name: count, Length: 274, dtype: int64

# %%
# List which years appear 255 times in ascending order
full_years_covered = years_covered[years_covered == 255]
full_years_covered.sort_index(inplace=True)
full_years_covered
# Out:
# year
# 1994    255
# 1995    255
# 1996    255
# 1997    255
# 1998    255
# 1999    255
# 2000    255
# 2001    255
# 2002    255
# 2003    255
# 2004    255
# 2005    255
# 2006    255
# 2007    255
# 2008    255
# 2009    255
# 2010    255
# 2011    255
# 2012    255
# 2013    255
# 2014    255
# 2015    255
# 2016    255
# 2017    255
# 2018    255
# 2019    255
# 2020    255
# 2021    255
# 2022    255
# 2023    255
# Name: count, dtype: int64

# %% [markdown]
# Rows exist for the years between 1994 and 2023 for all countries.
# Dropping years outside this range for better comparability.

# %%
# Dropping years outside the range of 1994 to 2023
df_co2 = df_co2[df_co2['year'].between(1994, 2023)].reset_index(drop=True)
df_co2
# Out:
#           country  year iso_code   population             gdp  cement_co2  \
# 0     Afghanistan  1994      AFG 16250799.000  7919856640.000       0.047
# 1     Afghanistan  1995      AFG 17065836.000 12307525632.000       0.047
# 2     Afghanistan  1996      AFG 17763265.000 12070125568.000       0.047
# 3     Afghanistan  1997      AFG 18452100.000 11850753024.000       0.047
# 4     Afghanistan  1998      AFG 19159996.000 11692171264.000       0.047
# ...           ...   ...      ...          ...             ...         ...
# 7645     Zimbabwe  2019      ZWE 15271377.000 25146417152.000       0.473
# 7646     Zimbabwe  2020      ZWE 15526888.000 23178706944.000       0.496
# 7647     Zimbabwe  2021      ZWE 15797220.000 25140088832.000       0.531
# 7648     Zimbabwe  2022      ZWE 16069061.000 25901586432.000       0.531
# 7649     Zimbabwe  2023      ZWE 16340829.000           0.000       0.531
#
#       cement_co2_per_capita    co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                     0.003  1.454          -0.033           -2.227  ...
# 1                     0.003  1.417          -0.037           -2.511  ...
# 2                     0.003  1.370          -0.047           -3.332  ...
# 3                     0.003  1.304          -0.066           -4.814  ...
# 4                     0.002  1.279          -0.026           -1.967  ...
# ...                     ...    ...             ...              ...  ...
# 7645                  0.031 10.263          -0.942           -8.411  ...
# 7646                  0.032  8.495          -1.768          -17.231  ...
# 7647                  0.034 10.204           1.709           20.120  ...
# 7648                  0.033 10.425           0.221            2.169  ...
# 7649                  0.032 11.164           0.739            7.090  ...
#
#       share_global_other_co2  share_of_temperature_change_from_ghg  \
# 0                      0.000                                 0.087
# 1                      0.000                                 0.085
# 2                      0.000                                 0.084
# 3                      0.000                                 0.083
# 4                      0.000                                 0.082
# ...                      ...                                   ...
# 7645                   0.000                                 0.106
# 7646                   0.000                                 0.105
# 7647                   0.000                                 0.104
# 7648                   0.000                                 0.103
# 7649                   0.000                                 0.102
#
#       temperature_change_from_ch4  temperature_change_from_co2  \
# 0                           0.000                        0.000
# 1                           0.000                        0.000
# 2                           0.000                        0.000
# 3                           0.000                        0.000
# 4                           0.000                        0.000
# ...                           ...                          ...
# 7645                        0.001                        0.001
# 7646                        0.001                        0.001
# 7647                        0.001                        0.001
# 7648                        0.001                        0.001
# 7649                        0.001                        0.001
#
#       temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 0                           0.001                        0.000     12.282
# 1                           0.001                        0.000     13.319
# 2                           0.001                        0.000     15.723
# 3                           0.001                        0.000     18.584
# 4                           0.001                        0.000     17.581
# ...                           ...                          ...        ...
# 7645                        0.002                        0.000     34.348
# 7646                        0.002                        0.000     31.323
# 7647                        0.002                        0.000     33.549
# 7648                        0.002                        0.000     33.772
# 7649                        0.002                        0.000     33.955
#
#       total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 0                        4.159      0.000            0.000
# 1                        4.321      0.000            0.000
# 2                        4.425      0.000            0.000
# 3                        4.466      0.000            0.000
# 4                        4.528      0.000            0.000
# ...                        ...        ...              ...
# 7645                    17.531     -0.027           -0.261
# 7646                    15.775      0.612            7.209
# 7647                    17.599      0.539            5.280
# 7648                    17.910      0.315            3.018
# 7649                    18.608      0.000            0.000
#
# [7650 rows x 79 columns]

# %% [markdown]
# Records dropped from 50191 to 7650 and will make for easier analysis

# %% [markdown]
# ### Nulls

# %%
# Calculate null percentage of each column
nulls_co2 = pd.Series(null_percentage(df_co2))
# Due to dropping rows with null values, the nulls are now 0.0 so will be using that value to count null
nulls_co2 = pd.Series(count_zeros(df_co2))
nulls_co2
# Out:
# country                                      0.000
# year                                         0.000
# iso_code                                    14.510
# population                                   9.804
# gdp                                         37.699
# cement_co2                                  37.804
# cement_co2_per_capita                       38.170
# co2                                          4.706
# co2_growth_abs                              12.444
# co2_growth_prct                             12.275
# co2_including_luc                           17.255
# co2_including_luc_growth_abs                18.824
# co2_including_luc_growth_prct               18.667
# co2_including_luc_per_capita                17.255
# co2_including_luc_per_gdp                   32.392
# co2_including_luc_per_unit_energy           22.954
# co2_per_capita                               9.595
# co2_per_gdp                                 31.634
# co2_per_unit_energy                         17.425
# coal_co2                                    45.503
# coal_co2_per_capita                         46.418
# consumption_co2                             44.078
# consumption_co2_per_capita                  48.261
# consumption_co2_per_gdp                     48.902
# cumulative_cement_co2                       35.974
# cumulative_co2                               8.026
# cumulative_co2_including_luc                17.255
# cumulative_coal_co2                         41.438
# cumulative_flaring_co2                      51.869
# cumulative_gas_co2                          47.242
# cumulative_luc_co2                          19.608
# cumulative_oil_co2                           8.732
# cumulative_other_co2                        76.863
# energy_per_capita                           19.569
# energy_per_gdp                              39.163
# flaring_co2                                 58.157
# flaring_co2_per_capita                      59.137
# gas_co2                                     48.641
# gas_co2_per_capita                          49.020
# ghg_excluding_lucf_per_capita               18.431
# ghg_per_capita                              18.039
# land_use_change_co2                         21.190
# land_use_change_co2_per_capita              21.556
# methane                                     15.686
# methane_per_capita                          18.039
# nitrous_oxide                               15.856
# nitrous_oxide_per_capita                    17.660
# oil_co2                                      8.732
# oil_co2_per_capita                           9.699
# other_co2_per_capita                        76.863
# other_industry_co2                          76.967
# primary_energy_consumption                  19.203
# share_global_cement_co2                     38.105
# share_global_co2                            15.922
# share_global_co2_including_luc              22.484
# share_global_coal_co2                       51.137
# share_global_cumulative_cement_co2          36.771
# share_global_cumulative_co2                 19.464
# share_global_cumulative_co2_including_luc   25.007
# share_global_cumulative_coal_co2            49.725
# share_global_cumulative_flaring_co2         54.288
# share_global_cumulative_gas_co2             51.804
# share_global_cumulative_luc_co2             27.020
# share_global_cumulative_oil_co2             13.438
# share_global_cumulative_other_co2           77.255
# share_global_flaring_co2                    58.392
# share_global_gas_co2                        50.601
# share_global_luc_co2                        24.013
# share_global_oil_co2                        11.647
# share_global_other_co2                      77.124
# share_of_temperature_change_from_ghg        17.660
# temperature_change_from_ch4                 56.039
# temperature_change_from_co2                 47.320
# temperature_change_from_ghg                 39.281
# temperature_change_from_n2o                 82.275
# total_ghg                                   15.686
# total_ghg_excluding_lucf                    16.078
# trade_co2                                   48.889
# trade_co2_share                             49.033
# dtype: float64

# %% [markdown]
# Significant null values contained in the original dataset.
# ISO country codes are used to identify countries in the dataset.

# %%
# Display values with ISO code 0 to identify potential issues
df_co2[df_co2['iso_code'] == 0]
# Out:
#      country  year iso_code     population                 gdp  cement_co2  \
# 30    Africa  1994        0  714502658.000               0.000      24.884
# 31    Africa  1995        0  732695476.000               0.000      26.900
# 32    Africa  1996        0  751473728.000               0.000      27.419
# 33    Africa  1997        0  770384702.000               0.000      27.539
# 34    Africa  1998        0  789981698.000               0.000      28.570
# ...      ...   ...      ...            ...                 ...         ...
# 7555   World  2019        0 7811293714.000 122149364826112.000    1623.120
# 7556   World  2020        0 7887001284.000 118590019731456.000    1638.271
# 7557   World  2021        0 7954448405.000 126004794228736.000    1696.308
# 7558   World  2022        0 8021407170.000 130112561348608.000    1601.124
# 7559   World  2023        0 8091734935.000               0.000    1569.346
#
#       cement_co2_per_capita       co2  co2_growth_abs  co2_growth_prct  ...  \
# 30                    0.035   790.234          83.792           11.861  ...
# 31                    0.037   844.549          54.316            6.873  ...
# 32                    0.037   872.284          27.735            3.284  ...
# 33                    0.036   893.938          21.654            2.482  ...
# 34                    0.036   912.482          18.544            2.074  ...
# ...                     ...       ...             ...              ...  ...
# 7555                  0.208 37104.273         373.850            1.018  ...
# 7556                  0.208 35126.527       -1977.750           -5.330  ...
# 7557                  0.213 36991.734        1865.208            5.310  ...
# 7558                  0.200 37293.836         302.100            0.817  ...
# 7559                  0.194 37791.570         497.738            1.335  ...
#
#       share_global_other_co2  share_of_temperature_change_from_ghg  \
# 30                     0.000                                 8.217
# 31                     0.000                                 8.275
# 32                     0.000                                 8.333
# 33                     0.000                                 8.378
# 34                     0.000                                 8.435
# ...                      ...                                   ...
# 7555                 100.000                               100.000
# 7556                 100.000                               100.000
# 7557                 100.000                               100.000
# 7558                 100.000                               100.000
# 7559                 100.000                               100.000
#
#       temperature_change_from_ch4  temperature_change_from_co2  \
# 30                          0.035                        0.045
# 31                          0.036                        0.046
# 32                          0.037                        0.047
# 33                          0.038                        0.048
# 34                          0.039                        0.049
# ...                           ...                          ...
# 7555                        0.401                        1.090
# 7556                        0.406                        1.107
# 7557                        0.411                        1.125
# 7558                        0.417                        1.143
# 7559                        0.422                        1.161
#
#       temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 30                          0.086                        0.006   3395.308
# 31                          0.088                        0.006   3460.717
# 32                          0.090                        0.006   3541.379
# 33                          0.092                        0.006   3588.715
# 34                          0.094                        0.006   3699.745
# ...                           ...                          ...        ...
# 7555                        1.571                        0.080  52796.523
# 7556                        1.595                        0.081  50792.543
# 7557                        1.619                        0.083  52938.793
# 7558                        1.644                        0.084  53327.215
# 7559                        1.668                        0.085  53816.852
#
#       total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 30                    1522.475    -74.274           -9.399
# 31                    1632.852    -92.724          -10.979
# 32                    1734.621   -120.434          -13.807
# 33                    1721.831   -121.838          -13.629
# 34                    1732.580    -93.231          -10.217
# ...                        ...        ...              ...
# 7555                 43147.367      0.004            0.000
# 7556                 41394.840      0.000            0.000
# 7557                 43391.352      0.004            0.000
# 7558                 43746.762      0.004            0.000
# 7559                 44114.785     -0.004            0.000
#
# [1110 rows x 79 columns]

# %%
# Display list of countries with ISO code 0
df_co2[df_co2['iso_code'] == 0]['country'].unique()
# Out:
# array(['Africa', 'Africa (GCP)', 'Asia', 'Asia (GCP)',
#        'Asia (excl. China and India)', 'Central America (GCP)', 'Europe',
#        'Europe (GCP)', 'Europe (excl. EU-27)', 'Europe (excl. EU-28)',
#        'European Union (27)', 'European Union (28)',
#        'High-income countries', 'International aviation',
#        'International shipping', 'International transport', 'Kosovo',
#        'Kuwaiti Oil Fires', 'Kuwaiti Oil Fires (GCP)',
#        'Least developed countries (Jones et al.)', 'Low-income countries',
#        'Lower-middle-income countries', 'Middle East (GCP)',
#        'Non-OECD (GCP)', 'North America', 'North America (GCP)',
#        'North America (excl. USA)', 'OECD (GCP)', 'OECD (Jones et al.)',
#        'Oceania', 'Oceania (GCP)', 'Ryukyu Islands',
#        'Ryukyu Islands (GCP)', 'South America', 'South America (GCP)',
#        'Upper-middle-income countries', 'World'], dtype=object)

# %%
# Countries with ISO code 0 identified as being aggregated
# Dropping all countries that do not have 
df_co2 = df_co2[df_co2['iso_code'] != 0]
df_co2
# Out:
#           country  year iso_code   population             gdp  cement_co2  \
# 0     Afghanistan  1994      AFG 16250799.000  7919856640.000       0.047
# 1     Afghanistan  1995      AFG 17065836.000 12307525632.000       0.047
# 2     Afghanistan  1996      AFG 17763265.000 12070125568.000       0.047
# 3     Afghanistan  1997      AFG 18452100.000 11850753024.000       0.047
# 4     Afghanistan  1998      AFG 19159996.000 11692171264.000       0.047
# ...           ...   ...      ...          ...             ...         ...
# 7645     Zimbabwe  2019      ZWE 15271377.000 25146417152.000       0.473
# 7646     Zimbabwe  2020      ZWE 15526888.000 23178706944.000       0.496
# 7647     Zimbabwe  2021      ZWE 15797220.000 25140088832.000       0.531
# 7648     Zimbabwe  2022      ZWE 16069061.000 25901586432.000       0.531
# 7649     Zimbabwe  2023      ZWE 16340829.000           0.000       0.531
#
#       cement_co2_per_capita    co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                     0.003  1.454          -0.033           -2.227  ...
# 1                     0.003  1.417          -0.037           -2.511  ...
# 2                     0.003  1.370          -0.047           -3.332  ...
# 3                     0.003  1.304          -0.066           -4.814  ...
# 4                     0.002  1.279          -0.026           -1.967  ...
# ...                     ...    ...             ...              ...  ...
# 7645                  0.031 10.263          -0.942           -8.411  ...
# 7646                  0.032  8.495          -1.768          -17.231  ...
# 7647                  0.034 10.204           1.709           20.120  ...
# 7648                  0.033 10.425           0.221            2.169  ...
# 7649                  0.032 11.164           0.739            7.090  ...
#
#       share_global_other_co2  share_of_temperature_change_from_ghg  \
# 0                      0.000                                 0.087
# 1                      0.000                                 0.085
# 2                      0.000                                 0.084
# 3                      0.000                                 0.083
# 4                      0.000                                 0.082
# ...                      ...                                   ...
# 7645                   0.000                                 0.106
# 7646                   0.000                                 0.105
# 7647                   0.000                                 0.104
# 7648                   0.000                                 0.103
# 7649                   0.000                                 0.102
#
#       temperature_change_from_ch4  temperature_change_from_co2  \
# 0                           0.000                        0.000
# 1                           0.000                        0.000
# 2                           0.000                        0.000
# 3                           0.000                        0.000
# 4                           0.000                        0.000
# ...                           ...                          ...
# 7645                        0.001                        0.001
# 7646                        0.001                        0.001
# 7647                        0.001                        0.001
# 7648                        0.001                        0.001
# 7649                        0.001                        0.001
#
#       temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 0                           0.001                        0.000     12.282
# 1                           0.001                        0.000     13.319
# 2                           0.001                        0.000     15.723
# 3                           0.001                        0.000     18.584
# 4                           0.001                        0.000     17.581
# ...                           ...                          ...        ...
# 7645                        0.002                        0.000     34.348
# 7646                        0.002                        0.000     31.323
# 7647                        0.002                        0.000     33.549
# 7648                        0.002                        0.000     33.772
# 7649                        0.002                        0.000     33.955
#
#       total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 0                        4.159      0.000            0.000
# 1                        4.321      0.000            0.000
# 2                        4.425      0.000            0.000
# 3                        4.466      0.000            0.000
# 4                        4.528      0.000            0.000
# ...                        ...        ...              ...
# 7645                    17.531     -0.027           -0.261
# 7646                    15.775      0.612            7.209
# 7647                    17.599      0.539            5.280
# 7648                    17.910      0.315            3.018
# 7649                    18.608      0.000            0.000
#
# [6540 rows x 79 columns]

# %%
nulls_co2 = pd.Series(count_zeros(df_co2))
nulls_co2
# Out:
# country                                      0.000
# year                                         0.000
# iso_code                                     0.000
# population                                   0.917
# gdp                                         27.278
# cement_co2                                  35.352
# cement_co2_per_capita                       35.780
# co2                                          2.141
# co2_growth_abs                               6.606
# co2_growth_prct                              6.391
# co2_including_luc                           11.009
# co2_including_luc_growth_abs                12.844
# co2_including_luc_growth_prct               12.661
# co2_including_luc_per_capita                11.009
# co2_including_luc_per_gdp                   28.165
# co2_including_luc_per_unit_energy           17.645
# co2_per_capita                               2.355
# co2_per_gdp                                 27.278
# co2_per_unit_energy                         11.391
# coal_co2                                    44.297
# coal_co2_per_capita                         45.367
# consumption_co2                             47.034
# consumption_co2_per_capita                  47.034
# consumption_co2_per_gdp                     47.477
# cumulative_cement_co2                       33.211
# cumulative_co2                               1.437
# cumulative_co2_including_luc                11.009
# cumulative_coal_co2                         40.000
# cumulative_flaring_co2                      51.498
# cumulative_gas_co2                          46.254
# cumulative_luc_co2                          13.761
# cumulative_oil_co2                           2.202
# cumulative_other_co2                        79.358
# energy_per_capita                           11.606
# energy_per_gdp                              28.991
# flaring_co2                                 58.853
# flaring_co2_per_capita                      60.000
# gas_co2                                     47.890
# gas_co2_per_capita                          48.165
# ghg_excluding_lucf_per_capita               10.550
# ghg_per_capita                              10.092
# land_use_change_co2                         15.612
# land_use_change_co2_per_capita              16.040
# methane                                     10.092
# methane_per_capita                          10.092
# nitrous_oxide                               10.291
# nitrous_oxide_per_capita                     9.648
# oil_co2                                      2.202
# oil_co2_per_capita                           2.416
# other_co2_per_capita                        79.358
# other_industry_co2                          79.480
# primary_energy_consumption                  11.177
# share_global_cement_co2                     35.703
# share_global_co2                            10.673
# share_global_co2_including_luc              17.125
# share_global_coal_co2                       50.887
# share_global_cumulative_cement_co2          34.144
# share_global_cumulative_co2                 14.755
# share_global_cumulative_co2_including_luc   20.076
# share_global_cumulative_coal_co2            49.694
# share_global_cumulative_flaring_co2         54.327
# share_global_cumulative_gas_co2             51.498
# share_global_cumulative_luc_co2             22.431
# share_global_cumulative_oil_co2              7.691
# share_global_cumulative_other_co2           79.817
# share_global_flaring_co2                    59.128
# share_global_gas_co2                        50.153
# share_global_luc_co2                        18.914
# share_global_oil_co2                         5.612
# share_global_other_co2                      79.664
# share_of_temperature_change_from_ghg        13.089
# temperature_change_from_ch4                 57.294
# temperature_change_from_co2                 47.095
# temperature_change_from_ghg                 37.691
# temperature_change_from_n2o                 87.982
# total_ghg                                   10.092
# total_ghg_excluding_lucf                    10.550
# trade_co2                                   47.492
# trade_co2_share                             47.477
# dtype: float64

# %%
# Display where population is 0.0
df_co2[df_co2['population'] == 0.0]
# Out:
#                country  year iso_code  population   gdp  cement_co2  \
# 240         Antarctica  1994      ATA       0.000 0.000       0.000
# 241         Antarctica  1995      ATA       0.000 0.000       0.000
# 242         Antarctica  1996      ATA       0.000 0.000       0.000
# 243         Antarctica  1997      ATA       0.000 0.000       0.000
# 244         Antarctica  1998      ATA       0.000 0.000       0.000
# 245         Antarctica  1999      ATA       0.000 0.000       0.000
# 246         Antarctica  2000      ATA       0.000 0.000       0.000
# 247         Antarctica  2001      ATA       0.000 0.000       0.000
# 248         Antarctica  2002      ATA       0.000 0.000       0.000
# 249         Antarctica  2003      ATA       0.000 0.000       0.000
# 250         Antarctica  2004      ATA       0.000 0.000       0.000
# 251         Antarctica  2005      ATA       0.000 0.000       0.000
# 252         Antarctica  2006      ATA       0.000 0.000       0.000
# 253         Antarctica  2007      ATA       0.000 0.000       0.000
# 254         Antarctica  2008      ATA       0.000 0.000       0.000
# 255         Antarctica  2009      ATA       0.000 0.000       0.000
# 256         Antarctica  2010      ATA       0.000 0.000       0.000
# 257         Antarctica  2011      ATA       0.000 0.000       0.000
# 258         Antarctica  2012      ATA       0.000 0.000       0.000
# 259         Antarctica  2013      ATA       0.000 0.000       0.000
# 260         Antarctica  2014      ATA       0.000 0.000       0.000
# 261         Antarctica  2015      ATA       0.000 0.000       0.000
# 262         Antarctica  2016      ATA       0.000 0.000       0.000
# 263         Antarctica  2017      ATA       0.000 0.000       0.000
# 264         Antarctica  2018      ATA       0.000 0.000       0.000
# 265         Antarctica  2019      ATA       0.000 0.000       0.000
# 266         Antarctica  2020      ATA       0.000 0.000       0.000
# 267         Antarctica  2021      ATA       0.000 0.000       0.000
# 268         Antarctica  2022      ATA       0.000 0.000       0.000
# 269         Antarctica  2023      ATA       0.000 0.000       0.000
# 1440  Christmas Island  1994      CXR       0.000 0.000       0.000
# 1441  Christmas Island  1995      CXR       0.000 0.000       0.000
# 1442  Christmas Island  1996      CXR       0.000 0.000       0.000
# 1443  Christmas Island  1997      CXR       0.000 0.000       0.000
# 1444  Christmas Island  1998      CXR       0.000 0.000       0.000
# 1445  Christmas Island  1999      CXR       0.000 0.000       0.000
# 1446  Christmas Island  2000      CXR       0.000 0.000       0.000
# 1447  Christmas Island  2001      CXR       0.000 0.000       0.000
# 1448  Christmas Island  2002      CXR       0.000 0.000       0.000
# 1449  Christmas Island  2003      CXR       0.000 0.000       0.000
# 1450  Christmas Island  2004      CXR       0.000 0.000       0.000
# 1451  Christmas Island  2005      CXR       0.000 0.000       0.000
# 1452  Christmas Island  2006      CXR       0.000 0.000       0.000
# 1453  Christmas Island  2007      CXR       0.000 0.000       0.000
# 1454  Christmas Island  2008      CXR       0.000 0.000       0.000
# 1455  Christmas Island  2009      CXR       0.000 0.000       0.000
# 1456  Christmas Island  2010      CXR       0.000 0.000       0.000
# 1457  Christmas Island  2011      CXR       0.000 0.000       0.000
# 1458  Christmas Island  2012      CXR       0.000 0.000       0.000
# 1459  Christmas Island  2013      CXR       0.000 0.000       0.000
# 1460  Christmas Island  2014      CXR       0.000 0.000       0.000
# 1461  Christmas Island  2015      CXR       0.000 0.000       0.000
# 1462  Christmas Island  2016      CXR       0.000 0.000       0.000
# 1463  Christmas Island  2017      CXR       0.000 0.000       0.000
# 1464  Christmas Island  2018      CXR       0.000 0.000       0.000
# 1465  Christmas Island  2019      CXR       0.000 0.000       0.000
# 1466  Christmas Island  2020      CXR       0.000 0.000       0.000
# 1467  Christmas Island  2021      CXR       0.000 0.000       0.000
# 1468  Christmas Island  2022      CXR       0.000 0.000       0.000
# 1469  Christmas Island  2023      CXR       0.000 0.000       0.000
#
#       cement_co2_per_capita   co2  co2_growth_abs  co2_growth_prct  ...  \
# 240                   0.000 0.015           0.000            0.000  ...
# 241                   0.000 0.004          -0.011          -75.000  ...
# 242                   0.000 0.004           0.000            0.000  ...
# 243                   0.000 0.004           0.000            0.000  ...
# 244                   0.000 0.004           0.000            0.000  ...
# 245                   0.000 0.004           0.000            0.000  ...
# 246                   0.000 0.004           0.000            0.000  ...
# 247                   0.000 0.004           0.000            0.000  ...
# 248                   0.000 0.004           0.000            0.000  ...
# 249                   0.000 0.004           0.000            0.000  ...
# 250                   0.000 0.007           0.004          100.000  ...
# 251                   0.000 0.007           0.000            0.000  ...
# 252                   0.000 0.007           0.000            0.000  ...
# 253                   0.000 0.011           0.004           50.000  ...
# 254                   0.000 0.000          -0.011         -100.000  ...
# 255                   0.000 0.000           0.000            0.000  ...
# 256                   0.000 0.000           0.000            0.000  ...
# 257                   0.000 0.000           0.000            0.000  ...
# 258                   0.000 0.000           0.000            0.000  ...
# 259                   0.000 0.000           0.000            0.000  ...
# 260                   0.000 0.000           0.000            0.000  ...
# 261                   0.000 0.000           0.000            0.000  ...
# 262                   0.000 0.000           0.000            0.000  ...
# 263                   0.000 0.000           0.000            0.000  ...
# 264                   0.000 0.000           0.000            0.000  ...
# 265                   0.000 0.000           0.000            0.000  ...
# 266                   0.000 0.000           0.000            0.000  ...
# 267                   0.000 0.000           0.000            0.000  ...
# 268                   0.000 0.000           0.000            0.000  ...
# 269                   0.000 0.000           0.000            0.000  ...
# 1440                  0.000 0.000           0.000            0.000  ...
# 1441                  0.000 0.000           0.000            0.000  ...
# 1442                  0.000 0.000           0.000            0.000  ...
# 1443                  0.000 0.000           0.000            0.000  ...
# 1444                  0.000 0.000           0.000            0.000  ...
# 1445                  0.000 0.000           0.000            0.000  ...
# 1446                  0.000 0.000           0.000            0.000  ...
# 1447                  0.000 0.000           0.000            0.000  ...
# 1448                  0.000 0.000           0.000            0.000  ...
# 1449                  0.000 0.000           0.000            0.000  ...
# 1450                  0.000 0.000           0.000            0.000  ...
# 1451                  0.000 0.000           0.000            0.000  ...
# 1452                  0.000 0.000           0.000            0.000  ...
# 1453                  0.000 0.000           0.000            0.000  ...
# 1454                  0.000 0.000           0.000            0.000  ...
# 1455                  0.000 0.000           0.000            0.000  ...
# 1456                  0.000 0.000           0.000            0.000  ...
# 1457                  0.000 0.000           0.000            0.000  ...
# 1458                  0.000 0.000           0.000            0.000  ...
# 1459                  0.000 0.000           0.000            0.000  ...
# 1460                  0.000 0.000           0.000            0.000  ...
# 1461                  0.000 0.000           0.000            0.000  ...
# 1462                  0.000 0.000           0.000            0.000  ...
# 1463                  0.000 0.000           0.000            0.000  ...
# 1464                  0.000 0.000           0.000            0.000  ...
# 1465                  0.000 0.000           0.000            0.000  ...
# 1466                  0.000 0.000           0.000            0.000  ...
# 1467                  0.000 0.000           0.000            0.000  ...
# 1468                  0.000 0.000           0.000            0.000  ...
# 1469                  0.000 0.000           0.000            0.000  ...
#
#       share_global_other_co2  share_of_temperature_change_from_ghg  \
# 240                    0.000                                 0.000
# 241                    0.000                                 0.000
# 242                    0.000                                 0.000
# 243                    0.000                                 0.000
# 244                    0.000                                 0.000
# 245                    0.000                                 0.000
# 246                    0.000                                 0.000
# 247                    0.000                                 0.000
# 248                    0.000                                 0.000
# 249                    0.000                                 0.000
# 250                    0.000                                 0.000
# 251                    0.000                                 0.000
# 252                    0.000                                 0.000
# 253                    0.000                                 0.000
# 254                    0.000                                 0.000
# 255                    0.000                                 0.000
# 256                    0.000                                 0.000
# 257                    0.000                                 0.000
# 258                    0.000                                 0.000
# 259                    0.000                                 0.000
# 260                    0.000                                 0.000
# 261                    0.000                                 0.000
# 262                    0.000                                 0.000
# 263                    0.000                                 0.000
# 264                    0.000                                 0.000
# 265                    0.000                                 0.000
# 266                    0.000                                 0.000
# 267                    0.000                                 0.000
# 268                    0.000                                 0.000
# 269                    0.000                                 0.000
# 1440                   0.000                                 0.000
# 1441                   0.000                                 0.000
# 1442                   0.000                                 0.000
# 1443                   0.000                                 0.000
# 1444                   0.000                                 0.000
# 1445                   0.000                                 0.000
# 1446                   0.000                                 0.000
# 1447                   0.000                                 0.000
# 1448                   0.000                                 0.000
# 1449                   0.000                                 0.000
# 1450                   0.000                                 0.000
# 1451                   0.000                                 0.000
# 1452                   0.000                                 0.000
# 1453                   0.000                                 0.000
# 1454                   0.000                                 0.000
# 1455                   0.000                                 0.000
# 1456                   0.000                                 0.000
# 1457                   0.000                                 0.000
# 1458                   0.000                                 0.000
# 1459                   0.000                                 0.000
# 1460                   0.000                                 0.000
# 1461                   0.000                                 0.000
# 1462                   0.000                                 0.000
# 1463                   0.000                                 0.000
# 1464                   0.000                                 0.000
# 1465                   0.000                                 0.000
# 1466                   0.000                                 0.000
# 1467                   0.000                                 0.000
# 1468                   0.000                                 0.000
# 1469                   0.000                                 0.000
#
#       temperature_change_from_ch4  temperature_change_from_co2  \
# 240                         0.000                        0.000
# 241                         0.000                        0.000
# 242                         0.000                        0.000
# 243                         0.000                        0.000
# 244                         0.000                        0.000
# 245                         0.000                        0.000
# 246                         0.000                        0.000
# 247                         0.000                        0.000
# 248                         0.000                        0.000
# 249                         0.000                        0.000
# 250                         0.000                        0.000
# 251                         0.000                        0.000
# 252                         0.000                        0.000
# 253                         0.000                        0.000
# 254                         0.000                        0.000
# 255                         0.000                        0.000
# 256                         0.000                        0.000
# 257                         0.000                        0.000
# 258                         0.000                        0.000
# 259                         0.000                        0.000
# 260                         0.000                        0.000
# 261                         0.000                        0.000
# 262                         0.000                        0.000
# 263                         0.000                        0.000
# 264                         0.000                        0.000
# 265                         0.000                        0.000
# 266                         0.000                        0.000
# 267                         0.000                        0.000
# 268                         0.000                        0.000
# 269                         0.000                        0.000
# 1440                        0.000                        0.000
# 1441                        0.000                        0.000
# 1442                        0.000                        0.000
# 1443                        0.000                        0.000
# 1444                        0.000                        0.000
# 1445                        0.000                        0.000
# 1446                        0.000                        0.000
# 1447                        0.000                        0.000
# 1448                        0.000                        0.000
# 1449                        0.000                        0.000
# 1450                        0.000                        0.000
# 1451                        0.000                        0.000
# 1452                        0.000                        0.000
# 1453                        0.000                        0.000
# 1454                        0.000                        0.000
# 1455                        0.000                        0.000
# 1456                        0.000                        0.000
# 1457                        0.000                        0.000
# 1458                        0.000                        0.000
# 1459                        0.000                        0.000
# 1460                        0.000                        0.000
# 1461                        0.000                        0.000
# 1462                        0.000                        0.000
# 1463                        0.000                        0.000
# 1464                        0.000                        0.000
# 1465                        0.000                        0.000
# 1466                        0.000                        0.000
# 1467                        0.000                        0.000
# 1468                        0.000                        0.000
# 1469                        0.000                        0.000
#
#       temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 240                         0.000                        0.000      0.000
# 241                         0.000                        0.000      0.000
# 242                         0.000                        0.000      0.000
# 243                         0.000                        0.000      0.000
# 244                         0.000                        0.000      0.000
# 245                         0.000                        0.000      0.000
# 246                         0.000                        0.000      0.000
# 247                         0.000                        0.000      0.000
# 248                         0.000                        0.000      0.000
# 249                         0.000                        0.000      0.000
# 250                         0.000                        0.000      0.000
# 251                         0.000                        0.000      0.000
# 252                         0.000                        0.000      0.000
# 253                         0.000                        0.000      0.000
# 254                         0.000                        0.000      0.000
# 255                         0.000                        0.000      0.000
# 256                         0.000                        0.000      0.000
# 257                         0.000                        0.000      0.000
# 258                         0.000                        0.000      0.000
# 259                         0.000                        0.000      0.000
# 260                         0.000                        0.000      0.000
# 261                         0.000                        0.000      0.000
# 262                         0.000                        0.000      0.000
# 263                         0.000                        0.000      0.000
# 264                         0.000                        0.000      0.000
# 265                         0.000                        0.000      0.000
# 266                         0.000                        0.000      0.000
# 267                         0.000                        0.000      0.000
# 268                         0.000                        0.000      0.000
# 269                         0.000                        0.000      0.000
# 1440                        0.000                        0.000      0.000
# 1441                        0.000                        0.000      0.000
# 1442                        0.000                        0.000      0.000
# 1443                        0.000                        0.000      0.000
# 1444                        0.000                        0.000      0.000
# 1445                        0.000                        0.000      0.000
# 1446                        0.000                        0.000      0.000
# 1447                        0.000                        0.000      0.000
# 1448                        0.000                        0.000      0.000
# 1449                        0.000                        0.000      0.000
# 1450                        0.000                        0.000      0.000
# 1451                        0.000                        0.000      0.000
# 1452                        0.000                        0.000      0.000
# 1453                        0.000                        0.000      0.000
# 1454                        0.000                        0.000      0.000
# 1455                        0.000                        0.000      0.000
# 1456                        0.000                        0.000      0.000
# 1457                        0.000                        0.000      0.000
# 1458                        0.000                        0.000      0.000
# 1459                        0.000                        0.000      0.000
# 1460                        0.000                        0.000      0.000
# 1461                        0.000                        0.000      0.000
# 1462                        0.000                        0.000      0.000
# 1463                        0.000                        0.000      0.000
# 1464                        0.000                        0.000      0.000
# 1465                        0.000                        0.000      0.000
# 1466                        0.000                        0.000      0.000
# 1467                        0.000                        0.000      0.000
# 1468                        0.000                        0.000      0.000
# 1469                        0.000                        0.000      0.000
#
#       total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 240                      0.000      0.000            0.000
# 241                      0.000      0.000            0.000
# 242                      0.000      0.000            0.000
# 243                      0.000      0.000            0.000
# 244                      0.000      0.000            0.000
# 245                      0.000      0.000            0.000
# 246                      0.000      0.000            0.000
# 247                      0.000      0.000            0.000
# 248                      0.000      0.000            0.000
# 249                      0.000      0.000            0.000
# 250                      0.000      0.000            0.000
# 251                      0.000      0.000            0.000
# 252                      0.000      0.000            0.000
# 253                      0.000      0.000            0.000
# 254                      0.000      0.000            0.000
# 255                      0.000      0.000            0.000
# 256                      0.000      0.000            0.000
# 257                      0.000      0.000            0.000
# 258                      0.000      0.000            0.000
# 259                      0.000      0.000            0.000
# 260                      0.000      0.000            0.000
# 261                      0.000      0.000            0.000
# 262                      0.000      0.000            0.000
# 263                      0.000      0.000            0.000
# 264                      0.000      0.000            0.000
# 265                      0.000      0.000            0.000
# 266                      0.000      0.000            0.000
# 267                      0.000      0.000            0.000
# 268                      0.000      0.000            0.000
# 269                      0.000      0.000            0.000
# 1440                     0.000      0.000            0.000
# 1441                     0.000      0.000            0.000
# 1442                     0.000      0.000            0.000
# 1443                     0.000      0.000            0.000
# 1444                     0.000      0.000            0.000
# 1445                     0.000      0.000            0.000
# 1446                     0.000      0.000            0.000
# 1447                     0.000      0.000            0.000
# 1448                     0.000      0.000            0.000
# 1449                     0.000      0.000            0.000
# 1450                     0.000      0.000            0.000
# 1451                     0.000      0.000            0.000
# 1452                     0.000      0.000            0.000
# 1453                     0.000      0.000            0.000
# 1454                     0.000      0.000            0.000
# 1455                     0.000      0.000            0.000
# 1456                     0.000      0.000            0.000
# 1457                     0.000      0.000            0.000
# 1458                     0.000      0.000            0.000
# 1459                     0.000      0.000            0.000
# 1460                     0.000      0.000            0.000
# 1461                     0.000      0.000            0.000
# 1462                     0.000      0.000            0.000
# 1463                     0.000      0.000            0.000
# 1464                     0.000      0.000            0.000
# 1465                     0.000      0.000            0.000
# 1466                     0.000      0.000            0.000
# 1467                     0.000      0.000            0.000
# 1468                     0.000      0.000            0.000
# 1469                     0.000      0.000            0.000
#
# [60 rows x 79 columns]

# %%
# No data from Antarctica or Christmas Island. Dropping these rows.
df_co2 = df_co2[~df_co2['country'].isin(['Antarctica', 'Christmas Island'])]
df_co2
# Out:
#           country  year iso_code   population             gdp  cement_co2  \
# 0     Afghanistan  1994      AFG 16250799.000  7919856640.000       0.047
# 1     Afghanistan  1995      AFG 17065836.000 12307525632.000       0.047
# 2     Afghanistan  1996      AFG 17763265.000 12070125568.000       0.047
# 3     Afghanistan  1997      AFG 18452100.000 11850753024.000       0.047
# 4     Afghanistan  1998      AFG 19159996.000 11692171264.000       0.047
# ...           ...   ...      ...          ...             ...         ...
# 7645     Zimbabwe  2019      ZWE 15271377.000 25146417152.000       0.473
# 7646     Zimbabwe  2020      ZWE 15526888.000 23178706944.000       0.496
# 7647     Zimbabwe  2021      ZWE 15797220.000 25140088832.000       0.531
# 7648     Zimbabwe  2022      ZWE 16069061.000 25901586432.000       0.531
# 7649     Zimbabwe  2023      ZWE 16340829.000           0.000       0.531
#
#       cement_co2_per_capita    co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                     0.003  1.454          -0.033           -2.227  ...
# 1                     0.003  1.417          -0.037           -2.511  ...
# 2                     0.003  1.370          -0.047           -3.332  ...
# 3                     0.003  1.304          -0.066           -4.814  ...
# 4                     0.002  1.279          -0.026           -1.967  ...
# ...                     ...    ...             ...              ...  ...
# 7645                  0.031 10.263          -0.942           -8.411  ...
# 7646                  0.032  8.495          -1.768          -17.231  ...
# 7647                  0.034 10.204           1.709           20.120  ...
# 7648                  0.033 10.425           0.221            2.169  ...
# 7649                  0.032 11.164           0.739            7.090  ...
#
#       share_global_other_co2  share_of_temperature_change_from_ghg  \
# 0                      0.000                                 0.087
# 1                      0.000                                 0.085
# 2                      0.000                                 0.084
# 3                      0.000                                 0.083
# 4                      0.000                                 0.082
# ...                      ...                                   ...
# 7645                   0.000                                 0.106
# 7646                   0.000                                 0.105
# 7647                   0.000                                 0.104
# 7648                   0.000                                 0.103
# 7649                   0.000                                 0.102
#
#       temperature_change_from_ch4  temperature_change_from_co2  \
# 0                           0.000                        0.000
# 1                           0.000                        0.000
# 2                           0.000                        0.000
# 3                           0.000                        0.000
# 4                           0.000                        0.000
# ...                           ...                          ...
# 7645                        0.001                        0.001
# 7646                        0.001                        0.001
# 7647                        0.001                        0.001
# 7648                        0.001                        0.001
# 7649                        0.001                        0.001
#
#       temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 0                           0.001                        0.000     12.282
# 1                           0.001                        0.000     13.319
# 2                           0.001                        0.000     15.723
# 3                           0.001                        0.000     18.584
# 4                           0.001                        0.000     17.581
# ...                           ...                          ...        ...
# 7645                        0.002                        0.000     34.348
# 7646                        0.002                        0.000     31.323
# 7647                        0.002                        0.000     33.549
# 7648                        0.002                        0.000     33.772
# 7649                        0.002                        0.000     33.955
#
#       total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 0                        4.159      0.000            0.000
# 1                        4.321      0.000            0.000
# 2                        4.425      0.000            0.000
# 3                        4.466      0.000            0.000
# 4                        4.528      0.000            0.000
# ...                        ...        ...              ...
# 7645                    17.531     -0.027           -0.261
# 7646                    15.775      0.612            7.209
# 7647                    17.599      0.539            5.280
# 7648                    17.910      0.315            3.018
# 7649                    18.608      0.000            0.000
#
# [6480 rows x 79 columns]

# %%
nulls_co2 = pd.Series(count_zeros(df_co2))
nulls_co2
# Out:
# country                                      0.000
# year                                         0.000
# iso_code                                     0.000
# population                                   0.000
# gdp                                         26.605
# cement_co2                                  34.753
# cement_co2_per_capita                       35.185
# co2                                          1.451
# co2_growth_abs                               5.802
# co2_growth_prct                              5.586
# co2_including_luc                           10.185
# co2_including_luc_growth_abs                12.037
# co2_including_luc_growth_prct               11.852
# co2_including_luc_per_capita                10.185
# co2_including_luc_per_gdp                   27.500
# co2_including_luc_per_unit_energy           16.883
# co2_per_capita                               1.451
# co2_per_gdp                                 26.605
# co2_per_unit_energy                         10.787
# coal_co2                                    43.781
# coal_co2_per_capita                         44.861
# consumption_co2                             46.543
# consumption_co2_per_capita                  46.543
# consumption_co2_per_gdp                     46.991
# cumulative_cement_co2                       32.593
# cumulative_co2                               1.451
# cumulative_co2_including_luc                10.185
# cumulative_coal_co2                         39.444
# cumulative_flaring_co2                      51.049
# cumulative_gas_co2                          45.756
# cumulative_luc_co2                          12.963
# cumulative_oil_co2                           1.512
# cumulative_other_co2                        79.167
# energy_per_capita                           10.787
# energy_per_gdp                              28.333
# flaring_co2                                 58.472
# flaring_co2_per_capita                      59.630
# gas_co2                                     47.407
# gas_co2_per_capita                          47.685
# ghg_excluding_lucf_per_capita                9.722
# ghg_per_capita                               9.259
# land_use_change_co2                         14.830
# land_use_change_co2_per_capita              15.262
# methane                                      9.259
# methane_per_capita                           9.259
# nitrous_oxide                                9.460
# nitrous_oxide_per_capita                     8.812
# oil_co2                                      1.512
# oil_co2_per_capita                           1.512
# other_co2_per_capita                        79.167
# other_industry_co2                          79.290
# primary_energy_consumption                  10.787
# share_global_cement_co2                     35.108
# share_global_co2                             9.846
# share_global_co2_including_luc              16.358
# share_global_coal_co2                       50.432
# share_global_cumulative_cement_co2          33.534
# share_global_cumulative_co2                 13.966
# share_global_cumulative_co2_including_luc   19.336
# share_global_cumulative_coal_co2            49.228
# share_global_cumulative_flaring_co2         53.904
# share_global_cumulative_gas_co2             51.049
# share_global_cumulative_luc_co2             21.713
# share_global_cumulative_oil_co2              6.836
# share_global_cumulative_other_co2           79.630
# share_global_flaring_co2                    58.750
# share_global_gas_co2                        49.691
# share_global_luc_co2                        18.164
# share_global_oil_co2                         4.738
# share_global_other_co2                      79.475
# share_of_temperature_change_from_ghg        12.284
# temperature_change_from_ch4                 56.898
# temperature_change_from_co2                 46.605
# temperature_change_from_ghg                 37.114
# temperature_change_from_n2o                 87.870
# total_ghg                                    9.259
# total_ghg_excluding_lucf                     9.722
# trade_co2                                   47.006
# trade_co2_share                             46.991
# dtype: float64

# %%
# Count zero values in gdp column for each country
df_co2[df_co2['gdp'] == 0.0].groupby('country').size().sort_values(ascending=False)
# Out:
# country
# Andorra                30
# Anguilla               30
# Antigua and Barbuda    30
# Bhutan                 30
# Belize                 30
#                        ..
# Venezuela               1
# Vietnam                 1
# Yemen                   1
# Zambia                  1
# Zimbabwe                1
# Length: 216, dtype: int64

# %%
# Count how many times each country has gdp == 0.0
zero_counts = df_co2[df_co2['gdp'] == 0.0].groupby('country').size()

# Drop where gdp of 0 for a country count is 30
df_co2 = df_co2[~df_co2['country'].isin(zero_counts[zero_counts == 30].index)]

# %%
df_co2[df_co2['gdp'] == 0.0].groupby('country').size().sort_values(ascending=False)
# Out:
# country
# Afghanistan    1
# Albania        1
# Algeria        1
# Angola         1
# Argentina      1
#               ..
# Venezuela      1
# Vietnam        1
# Yemen          1
# Zambia         1
# Zimbabwe       1
# Length: 164, dtype: int64

# %%
# Remaining countries with gdp == 0.0 count as only one per country
# Inserting mean of gdp for these countries
mean_gdp = df_co2[df_co2['gdp'] != 0.0].groupby('country')['gdp'].mean()
df_co2.loc[df_co2['gdp'] == 0.0, 'gdp'] = df_co2['country'].map(mean_gdp)
df_co2
# Out:
#           country  year iso_code   population             gdp  cement_co2  \
# 0     Afghanistan  1994      AFG 16250799.000  7919856640.000       0.047
# 1     Afghanistan  1995      AFG 17065836.000 12307525632.000       0.047
# 2     Afghanistan  1996      AFG 17763265.000 12070125568.000       0.047
# 3     Afghanistan  1997      AFG 18452100.000 11850753024.000       0.047
# 4     Afghanistan  1998      AFG 19159996.000 11692171264.000       0.047
# ...           ...   ...      ...          ...             ...         ...
# 7645     Zimbabwe  2019      ZWE 15271377.000 25146417152.000       0.473
# 7646     Zimbabwe  2020      ZWE 15526888.000 23178706944.000       0.496
# 7647     Zimbabwe  2021      ZWE 15797220.000 25140088832.000       0.531
# 7648     Zimbabwe  2022      ZWE 16069061.000 25901586432.000       0.531
# 7649     Zimbabwe  2023      ZWE 16340829.000 23049979833.379       0.531
#
#       cement_co2_per_capita    co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                     0.003  1.454          -0.033           -2.227  ...
# 1                     0.003  1.417          -0.037           -2.511  ...
# 2                     0.003  1.370          -0.047           -3.332  ...
# 3                     0.003  1.304          -0.066           -4.814  ...
# 4                     0.002  1.279          -0.026           -1.967  ...
# ...                     ...    ...             ...              ...  ...
# 7645                  0.031 10.263          -0.942           -8.411  ...
# 7646                  0.032  8.495          -1.768          -17.231  ...
# 7647                  0.034 10.204           1.709           20.120  ...
# 7648                  0.033 10.425           0.221            2.169  ...
# 7649                  0.032 11.164           0.739            7.090  ...
#
#       share_global_other_co2  share_of_temperature_change_from_ghg  \
# 0                      0.000                                 0.087
# 1                      0.000                                 0.085
# 2                      0.000                                 0.084
# 3                      0.000                                 0.083
# 4                      0.000                                 0.082
# ...                      ...                                   ...
# 7645                   0.000                                 0.106
# 7646                   0.000                                 0.105
# 7647                   0.000                                 0.104
# 7648                   0.000                                 0.103
# 7649                   0.000                                 0.102
#
#       temperature_change_from_ch4  temperature_change_from_co2  \
# 0                           0.000                        0.000
# 1                           0.000                        0.000
# 2                           0.000                        0.000
# 3                           0.000                        0.000
# 4                           0.000                        0.000
# ...                           ...                          ...
# 7645                        0.001                        0.001
# 7646                        0.001                        0.001
# 7647                        0.001                        0.001
# 7648                        0.001                        0.001
# 7649                        0.001                        0.001
#
#       temperature_change_from_ghg  temperature_change_from_n2o  total_ghg  \
# 0                           0.001                        0.000     12.282
# 1                           0.001                        0.000     13.319
# 2                           0.001                        0.000     15.723
# 3                           0.001                        0.000     18.584
# 4                           0.001                        0.000     17.581
# ...                           ...                          ...        ...
# 7645                        0.002                        0.000     34.348
# 7646                        0.002                        0.000     31.323
# 7647                        0.002                        0.000     33.549
# 7648                        0.002                        0.000     33.772
# 7649                        0.002                        0.000     33.955
#
#       total_ghg_excluding_lucf  trade_co2  trade_co2_share
# 0                        4.159      0.000            0.000
# 1                        4.321      0.000            0.000
# 2                        4.425      0.000            0.000
# 3                        4.466      0.000            0.000
# 4                        4.528      0.000            0.000
# ...                        ...        ...              ...
# 7645                    17.531     -0.027           -0.261
# 7646                    15.775      0.612            7.209
# 7647                    17.599      0.539            5.280
# 7648                    17.910      0.315            3.018
# 7649                    18.608      0.000            0.000
#
# [4920 rows x 79 columns]

# %%
# All gdp null values present
df_co2[df_co2['gdp'] == 0.0].groupby('country').size().sort_values(ascending=False)
# Out:
# Series([], dtype: int64)

# %%
nulls_co2 = pd.Series(count_zeros(df_co2))
nulls_co2
# Out:
# country                                      0.000
# year                                         0.000
# iso_code                                     0.000
# population                                   0.000
# gdp                                          0.000
# cement_co2                                  17.459
# cement_co2_per_capita                       18.028
# co2                                          0.000
# co2_growth_abs                               0.691
# co2_growth_prct                              0.671
# co2_including_luc                            1.220
# co2_including_luc_growth_abs                 1.321
# co2_including_luc_growth_prct                1.240
# co2_including_luc_per_capita                 1.220
# co2_including_luc_per_gdp                    4.512
# co2_including_luc_per_unit_energy            5.224
# co2_per_capita                               0.000
# co2_per_gdp                                  3.333
# co2_per_unit_energy                          4.004
# coal_co2                                    28.374
# coal_co2_per_capita                         30.041
# consumption_co2                             30.183
# consumption_co2_per_capita                  30.183
# consumption_co2_per_gdp                     30.183
# cumulative_cement_co2                       15.813
# cumulative_co2                               0.000
# cumulative_co2_including_luc                 1.220
# cumulative_coal_co2                         24.919
# cumulative_flaring_co2                      38.089
# cumulative_gas_co2                          31.870
# cumulative_luc_co2                           1.829
# cumulative_oil_co2                           0.000
# cumulative_other_co2                        72.561
# energy_per_capita                            4.004
# energy_per_gdp                               5.610
# flaring_co2                                 47.825
# flaring_co2_per_capita                      49.350
# gas_co2                                     33.821
# gas_co2_per_capita                          34.187
# ghg_excluding_lucf_per_capita                1.220
# ghg_per_capita                               0.610
# land_use_change_co2                          2.459
# land_use_change_co2_per_capita               2.500
# methane                                      0.610
# methane_per_capita                           0.610
# nitrous_oxide                                0.610
# nitrous_oxide_per_capita                     0.610
# oil_co2                                      0.000
# oil_co2_per_capita                           0.000
# other_co2_per_capita                        72.561
# other_industry_co2                          72.724
# primary_energy_consumption                   4.004
# share_global_cement_co2                     17.907
# share_global_co2                             1.524
# share_global_co2_including_luc               2.581
# share_global_coal_co2                       36.159
# share_global_cumulative_cement_co2          17.012
# share_global_cumulative_co2                  2.561
# share_global_cumulative_co2_including_luc    4.167
# share_global_cumulative_coal_co2            34.106
# share_global_cumulative_flaring_co2         41.626
# share_global_cumulative_gas_co2             37.317
# share_global_cumulative_luc_co2              7.276
# share_global_cumulative_oil_co2              0.711
# share_global_cumulative_other_co2           73.171
# share_global_flaring_co2                    48.171
# share_global_gas_co2                        35.894
# share_global_luc_co2                         4.797
# share_global_oil_co2                         0.122
# share_global_other_co2                      72.967
# share_of_temperature_change_from_ghg         2.215
# temperature_change_from_ch4                 45.061
# temperature_change_from_co2                 31.280
# temperature_change_from_ghg                 19.898
# temperature_change_from_n2o                 84.411
# total_ghg                                    0.610
# total_ghg_excluding_lucf                     1.220
# trade_co2                                   30.793
# trade_co2_share                             30.772
# dtype: float64

# %%
# Display only columns with no null values
nulls_co2[nulls_co2 == 0]
# Out:
# country              0.000
# year                 0.000
# iso_code             0.000
# population           0.000
# gdp                  0.000
# co2                  0.000
# co2_per_capita       0.000
# cumulative_co2       0.000
# cumulative_oil_co2   0.000
# oil_co2              0.000
# oil_co2_per_capita   0.000
# dtype: float64

# %%
# Store columns with no null values as completed dataframe
df_co2 = df_co2[nulls_co2[nulls_co2 == 0].index].reset_index(drop=True)
df_co2
# Out:
#           country  year iso_code   population             gdp    co2  \
# 0     Afghanistan  1994      AFG 16250799.000  7919856640.000  1.454
# 1     Afghanistan  1995      AFG 17065836.000 12307525632.000  1.417
# 2     Afghanistan  1996      AFG 17763265.000 12070125568.000  1.370
# 3     Afghanistan  1997      AFG 18452100.000 11850753024.000  1.304
# 4     Afghanistan  1998      AFG 19159996.000 11692171264.000  1.279
# ...           ...   ...      ...          ...             ...    ...
# 4915     Zimbabwe  2019      ZWE 15271377.000 25146417152.000 10.263
# 4916     Zimbabwe  2020      ZWE 15526888.000 23178706944.000  8.495
# 4917     Zimbabwe  2021      ZWE 15797220.000 25140088832.000 10.204
# 4918     Zimbabwe  2022      ZWE 16069061.000 25901586432.000 10.425
# 4919     Zimbabwe  2023      ZWE 16340829.000 23049979833.379 11.164
#
#       co2_per_capita  cumulative_co2  cumulative_oil_co2  oil_co2  \
# 0              0.089          64.941              33.346    1.032
# 1              0.083          66.358              34.357    1.011
# 2              0.077          67.728              35.343    0.986
# 3              0.071          69.032              36.292    0.949
# 4              0.067          70.311              37.234    0.942
# ...              ...             ...                 ...      ...
# 4915           0.672         774.802             144.767    3.778
# 4916           0.547         783.296             147.830    3.063
# 4917           0.646         793.500             151.565    3.735
# 4918           0.649         803.925             154.944    3.379
# 4919           0.683         815.089             158.306    3.362
#
#       oil_co2_per_capita
# 0                  0.064
# 1                  0.059
# 2                  0.055
# 3                  0.051
# 4                  0.049
# ...                  ...
# 4915               0.247
# 4916               0.197
# 4917               0.236
# 4918               0.210
# 4919               0.206
#
# [4920 rows x 11 columns]

# %% [markdown]
# ### Duplicates

# %%
# Confirm number of duplicate rows
duplicate_rows_count = duplicate_rows(df_co2).shape[0]
print(f"Number of duplicated rows: {duplicate_rows_count}")
# Out:
# Number of duplicated rows: 0

# %% [markdown]
# No duplicates found in the dataset.

# %% [markdown]
# ### Data Format

# %%
# All data typing is consistent within each column
df_co2.head()
# Out:
#        country  year iso_code   population             gdp   co2  \
# 0  Afghanistan  1994      AFG 16250799.000  7919856640.000 1.454
# 1  Afghanistan  1995      AFG 17065836.000 12307525632.000 1.417
# 2  Afghanistan  1996      AFG 17763265.000 12070125568.000 1.370
# 3  Afghanistan  1997      AFG 18452100.000 11850753024.000 1.304
# 4  Afghanistan  1998      AFG 19159996.000 11692171264.000 1.279
#
#    co2_per_capita  cumulative_co2  cumulative_oil_co2  oil_co2  \
# 0           0.089          64.941              33.346    1.032
# 1           0.083          66.358              34.357    1.011
# 2           0.077          67.728              35.343    0.986
# 3           0.071          69.032              36.292    0.949
# 4           0.067          70.311              37.234    0.942
#
#    oil_co2_per_capita
# 0               0.064
# 1               0.059
# 2               0.055
# 3               0.051
# 4               0.049

# %% [markdown]
# No data formatting issues found.

# %% [markdown]
# ### Column Typing

# %%
# Confirm data types of each column
column_types(df_co2)
# Out:
# country                object
# year                    int64
# iso_code               object
# population            float64
# gdp                   float64
# co2                   float64
# co2_per_capita        float64
# cumulative_co2        float64
# cumulative_oil_co2    float64
# oil_co2               float64
# oil_co2_per_capita    float64
# dtype: object

# %%
# Convert population column to int
df_co2['population'] = df_co2['population'].astype(int)

# Convert gdp column to int as no values contain a decimal
df_co2['gdp'] = df_co2['gdp'].astype(int)

df_co2
# Out:
#           country  year iso_code  population          gdp    co2  \
# 0     Afghanistan  1994      AFG    16250799   7919856640  1.454
# 1     Afghanistan  1995      AFG    17065836  12307525632  1.417
# 2     Afghanistan  1996      AFG    17763265  12070125568  1.370
# 3     Afghanistan  1997      AFG    18452100  11850753024  1.304
# 4     Afghanistan  1998      AFG    19159996  11692171264  1.279
# ...           ...   ...      ...         ...          ...    ...
# 4915     Zimbabwe  2019      ZWE    15271377  25146417152 10.263
# 4916     Zimbabwe  2020      ZWE    15526888  23178706944  8.495
# 4917     Zimbabwe  2021      ZWE    15797220  25140088832 10.204
# 4918     Zimbabwe  2022      ZWE    16069061  25901586432 10.425
# 4919     Zimbabwe  2023      ZWE    16340829  23049979833 11.164
#
#       co2_per_capita  cumulative_co2  cumulative_oil_co2  oil_co2  \
# 0              0.089          64.941              33.346    1.032
# 1              0.083          66.358              34.357    1.011
# 2              0.077          67.728              35.343    0.986
# 3              0.071          69.032              36.292    0.949
# 4              0.067          70.311              37.234    0.942
# ...              ...             ...                 ...      ...
# 4915           0.672         774.802             144.767    3.778
# 4916           0.547         783.296             147.830    3.063
# 4917           0.646         793.500             151.565    3.735
# 4918           0.649         803.925             154.944    3.379
# 4919           0.683         815.089             158.306    3.362
#
#       oil_co2_per_capita
# 0                  0.064
# 1                  0.059
# 2                  0.055
# 3                  0.051
# 4                  0.049
# ...                  ...
# 4915               0.247
# 4916               0.197
# 4917               0.236
# 4918               0.210
# 4919               0.206
#
# [4920 rows x 11 columns]

# %%
# Confirm data types of each column
column_types(df_co2)
# Out:
# country                object
# year                    int64
# iso_code               object
# population              int64
# gdp                     int64
# co2                   float64
# co2_per_capita        float64
# cumulative_co2        float64
# cumulative_oil_co2    float64
# oil_co2               float64
# oil_co2_per_capita    float64
# dtype: object

# %% [markdown]
# ## Dataset 1: Additional Transformation

# %%
# Add additional column that will check the country and select a suitable region for association
# Define region mapping for all 255 countries in the current dataframe
region_map = {
    # Africa
    'Algeria': 'Africa', 'Angola': 'Africa', 'Benin': 'Africa', 'Botswana': 'Africa', 'Burkina Faso': 'Africa',
    'Burundi': 'Africa', 'Cabo Verde': 'Africa', 'Cameroon': 'Africa', 'Central African Republic': 'Africa',
    'Chad': 'Africa', 'Comoros': 'Africa', 'Congo': 'Africa', 'Democratic Republic of Congo': 'Africa',
    'Djibouti': 'Africa', 'Egypt': 'Africa', 'Equatorial Guinea': 'Africa', 'Eritrea': 'Africa', 'Eswatini': 'Africa',
    'Ethiopia': 'Africa', 'Gabon': 'Africa', 'Gambia': 'Africa', 'Ghana': 'Africa', 'Guinea': 'Africa',
    'Guinea-Bissau': 'Africa', 'Ivory Coast': 'Africa', "Cote d'Ivoire": 'Africa', 'Kenya': 'Africa', 'Lesotho': 'Africa',
    'Liberia': 'Africa', 'Libya': 'Africa', 'Madagascar': 'Africa', 'Malawi': 'Africa', 'Mali': 'Africa',
    'Mauritania': 'Africa', 'Mauritius': 'Africa', 'Morocco': 'Africa', 'Mozambique': 'Africa', 'Namibia': 'Africa',
    'Niger': 'Africa', 'Nigeria': 'Africa', 'Rwanda': 'Africa', 'Sao Tome and Principe': 'Africa', 'Senegal': 'Africa',
    'Seychelles': 'Africa', 'Sierra Leone': 'Africa', 'Somalia': 'Africa', 'South Africa': 'Africa', 'South Sudan': 'Africa',
    'Sudan': 'Africa', 'Tanzania': 'Africa', 'Togo': 'Africa', 'Tunisia': 'Africa', 'Uganda': 'Africa',
    'Zambia': 'Africa', 'Zimbabwe': 'Africa',

    # Asia
    'Afghanistan': 'Asia', 'Armenia': 'Asia', 'Azerbaijan': 'Asia', 'Bahrain': 'Asia', 'Bangladesh': 'Asia',
    'Bhutan': 'Asia', 'Brunei': 'Asia', 'Cambodia': 'Asia', 'China': 'Asia', 'Cyprus': 'Asia', 'Georgia': 'Asia',
    'India': 'Asia', 'Indonesia': 'Asia', 'Iran': 'Asia', 'Iraq': 'Asia', 'Israel': 'Asia', 'Japan': 'Asia',
    'Jordan': 'Asia', 'Kazakhstan': 'Asia', 'Kuwait': 'Asia', 'Kyrgyzstan': 'Asia', 'Laos': 'Asia', 'Lebanon': 'Asia',
    'Malaysia': 'Asia', 'Maldives': 'Asia', 'Mongolia': 'Asia', 'Myanmar': 'Asia', 'Nepal': 'Asia', 'North Korea': 'Asia',
    'Oman': 'Asia', 'Pakistan': 'Asia', 'Palestine': 'Asia', 'Philippines': 'Asia', 'Qatar': 'Asia', 'Saudi Arabia': 'Asia',
    'Singapore': 'Asia', 'South Korea': 'Asia', 'Sri Lanka': 'Asia', 'Syria': 'Asia', 'Taiwan': 'Asia', 'Tajikistan': 'Asia',
    'Thailand': 'Asia', 'Timor': 'Asia', 'East Timor': 'Asia', 'Turkey': 'Asia', 'Turkmenistan': 'Asia', 'United Arab Emirates': 'Asia',
    'Uzbekistan': 'Asia', 'Vietnam': 'Asia', 'Yemen': 'Asia',

    # Europe
    'Albania': 'Europe', 'Andorra': 'Europe', 'Austria': 'Europe', 'Belarus': 'Europe', 'Belgium': 'Europe',
    'Bosnia and Herzegovina': 'Europe', 'Bulgaria': 'Europe', 'Croatia': 'Europe', 'Czechia': 'Europe', 'Denmark': 'Europe',
    'Estonia': 'Europe', 'Finland': 'Europe', 'France': 'Europe', 'Germany': 'Europe', 'Greece': 'Europe', 'Hungary': 'Europe',
    'Iceland': 'Europe', 'Ireland': 'Europe', 'Italy': 'Europe', 'Kosovo': 'Europe', 'Latvia': 'Europe', 'Liechtenstein': 'Europe',
    'Lithuania': 'Europe', 'Luxembourg': 'Europe', 'Malta': 'Europe', 'Moldova': 'Europe', 'Monaco': 'Europe', 'Montenegro': 'Europe',
    'Netherlands': 'Europe', 'North Macedonia': 'Europe', 'Norway': 'Europe', 'Poland': 'Europe', 'Portugal': 'Europe',
    'Romania': 'Europe', 'Russia': 'Europe', 'San Marino': 'Europe', 'Serbia': 'Europe', 'Slovakia': 'Europe', 'Slovenia': 'Europe',
    'Spain': 'Europe', 'Sweden': 'Europe', 'Switzerland': 'Europe', 'Ukraine': 'Europe', 'United Kingdom': 'Europe', 'Vatican': 'Europe',

    # North America
    'Antigua and Barbuda': 'North America', 'Bahamas': 'North America', 'Barbados': 'North America', 'Belize': 'North America',
    'Canada': 'North America', 'Costa Rica': 'North America', 'Cuba': 'North America', 'Dominica': 'North America',
    'Dominican Republic': 'North America', 'El Salvador': 'North America', 'Grenada': 'North America', 'Guatemala': 'North America',
    'Haiti': 'North America', 'Honduras': 'North America', 'Jamaica': 'North America', 'Mexico': 'North America',
    'Nicaragua': 'North America', 'Panama': 'North America', 'Saint Kitts and Nevis': 'North America', 'Saint Lucia': 'North America',
    'Saint Vincent and the Grenadines': 'North America', 'Trinidad and Tobago': 'North America', 'United States': 'North America',

    # South America
    'Argentina': 'South America', 'Bolivia': 'South America', 'Brazil': 'South America', 'Chile': 'South America',
    'Colombia': 'South America', 'Ecuador': 'South America', 'Guyana': 'South America', 'Paraguay': 'South America',
    'Peru': 'South America', 'Suriname': 'South America', 'Uruguay': 'South America', 'Venezuela': 'South America',

    # Oceania
    'Australia': 'Oceania', 'Fiji': 'Oceania', 'Kiribati': 'Oceania', 'Marshall Islands': 'Oceania', 'Micronesia (country)': 'Oceania',
    'Nauru': 'Oceania', 'New Zealand': 'Oceania', 'Palau': 'Oceania', 'Papua New Guinea': 'Oceania', 'Samoa': 'Oceania',
    'Solomon Islands': 'Oceania', 'Tonga': 'Oceania', 'Tuvalu': 'Oceania', 'Vanuatu': 'Oceania',

    # Other/Unclassified
    'Hong Kong': 'Other', 'Macao': 'Other', 'Greenland': 'Other', 'Bermuda': 'Other', 'Aruba': 'Other',
    'Curaçao': 'Other', 'Sint Maarten (Dutch part)': 'Other', 'Bonaire Sint Eustatius and Saba': 'Other',
    'Montserrat': 'Other', 'Anguilla': 'Other', 'British Virgin Islands': 'Other', 'Cayman Islands': 'Other',
    'Falkland Islands': 'Other', 'French Polynesia': 'Other', 'Gibraltar': 'Other', 'Guadeloupe': 'Other',
    'Martinique': 'Other', 'Mayotte': 'Other', 'New Caledonia': 'Other', 'Niue': 'Other', 'Réunion': 'Other',
    'Saint Helena': 'Other', 'Saint Pierre and Miquelon': 'Other', 'Turks and Caicos Islands': 'Other',
    'Wallis and Futuna': 'Other', 'Faroe Islands': 'Other', 'Saint Barthélemy': 'Other', 'Saint Martin (French part)': 'Other',
    'Kosovo': 'Other', 'Ryukyu Islands': 'Other', 'Ryukyu Islands (GCP)': 'Other', 'Kuwaiti Oil Fires': 'Other',
    'Kuwaiti Oil Fires (GCP)': 'Other', 'Christmas Island': 'Other'
}

def assign_region(country):
    return region_map.get(country, 'Other')

df_co2['region'] = df_co2['country'].apply(assign_region)

# %%
df_co2
# Out:
#           country  year iso_code  population          gdp    co2  \
# 0     Afghanistan  1994      AFG    16250799   7919856640  1.454
# 1     Afghanistan  1995      AFG    17065836  12307525632  1.417
# 2     Afghanistan  1996      AFG    17763265  12070125568  1.370
# 3     Afghanistan  1997      AFG    18452100  11850753024  1.304
# 4     Afghanistan  1998      AFG    19159996  11692171264  1.279
# ...           ...   ...      ...         ...          ...    ...
# 4915     Zimbabwe  2019      ZWE    15271377  25146417152 10.263
# 4916     Zimbabwe  2020      ZWE    15526888  23178706944  8.495
# 4917     Zimbabwe  2021      ZWE    15797220  25140088832 10.204
# 4918     Zimbabwe  2022      ZWE    16069061  25901586432 10.425
# 4919     Zimbabwe  2023      ZWE    16340829  23049979833 11.164
#
#       co2_per_capita  cumulative_co2  cumulative_oil_co2  oil_co2  \
# 0              0.089          64.941              33.346    1.032
# 1              0.083          66.358              34.357    1.011
# 2              0.077          67.728              35.343    0.986
# 3              0.071          69.032              36.292    0.949
# 4              0.067          70.311              37.234    0.942
# ...              ...             ...                 ...      ...
# 4915           0.672         774.802             144.767    3.778
# 4916           0.547         783.296             147.830    3.063
# 4917           0.646         793.500             151.565    3.735
# 4918           0.649         803.925             154.944    3.379
# 4919           0.683         815.089             158.306    3.362
#
#       oil_co2_per_capita  region
# 0                  0.064    Asia
# 1                  0.059    Asia
# 2                  0.055    Asia
# 3                  0.051    Asia
# 4                  0.049    Asia
# ...                  ...     ...
# 4915               0.247  Africa
# 4916               0.197  Africa
# 4917               0.236  Africa
# 4918               0.210  Africa
# 4919               0.206  Africa
#
# [4920 rows x 12 columns]

# %%
# Check for null in region
print(f"Missing regions: {df_co2['region'].isnull().sum()}")
# Out:
# Missing regions: 0

# %% [markdown]
# ## Dataset 2: Global Energy Consumption

# %%
# Import dataset into df_energy dataframe
df_energy = import_data('../data/extract/data1.csv')

# Drop unnecessary index column
df_energy.drop(columns=['Unnamed: 0'], inplace=True, errors='ignore')
df_energy
# Out:
#              country  year iso_code   population             gdp  \
# 0      ASEAN (Ember)  2000      NaN          NaN             NaN
# 1      ASEAN (Ember)  2001      NaN          NaN             NaN
# 2      ASEAN (Ember)  2002      NaN          NaN             NaN
# 3      ASEAN (Ember)  2003      NaN          NaN             NaN
# 4      ASEAN (Ember)  2004      NaN          NaN             NaN
# ...              ...   ...      ...          ...             ...
# 23190       Zimbabwe  2020      ZWE 15526837.000 23178706944.000
# 23191       Zimbabwe  2021      ZWE 15797165.000 25140088832.000
# 23192       Zimbabwe  2022      ZWE 16069010.000 25901586432.000
# 23193       Zimbabwe  2023      ZWE 16340778.000             NaN
# 23194       Zimbabwe  2024      ZWE 16634317.000             NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 23190                      NaN                    0.000
# 23191                      NaN                    0.000
# 23192                      NaN                    0.000
# 23193                      NaN                    0.000
# 23194                      NaN                    0.000
#
#        biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 0                          NaN                  NaN                      NaN
# 1                          NaN                  NaN                      NaN
# 2                          NaN                  NaN                      NaN
# 3                          NaN                  NaN                      NaN
# 4                          NaN                  NaN                      NaN
# ...                        ...                  ...                      ...
# 23190                    0.000                0.000                    6.440
# 23191                    0.000                0.000                    6.963
# 23192                    0.000                0.000                    6.845
# 23193                    0.000                0.000                    7.344
# 23194                    0.000                0.000                      NaN
#
#        ...  solar_share_elec  solar_share_energy  wind_cons_change_pct  \
# 0      ...             0.000                 NaN                   NaN
# 1      ...             0.000                 NaN                   NaN
# 2      ...             0.000                 NaN                   NaN
# 3      ...             0.000                 NaN                   NaN
# 4      ...             0.000                 NaN                   NaN
# ...    ...               ...                 ...                   ...
# 23190  ...             0.298                 NaN                   NaN
# 23191  ...             0.233                 NaN                   NaN
# 23192  ...             0.336                 NaN                   NaN
# 23193  ...             0.361                 NaN                   NaN
# 23194  ...               NaN                 NaN                   NaN
#
#        wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 0                       NaN               NaN                   NaN
# 1                       NaN               NaN                   NaN
# 2                       NaN               NaN                   NaN
# 3                       NaN               NaN                   NaN
# 4                       NaN               NaN                   NaN
# ...                     ...               ...                   ...
# 23190                   NaN               NaN                 0.000
# 23191                   NaN               NaN                 0.000
# 23192                   NaN               NaN                 0.000
# 23193                   NaN               NaN                 0.000
# 23194                   NaN               NaN                   NaN
#
#        wind_electricity  wind_energy_per_capita  wind_share_elec  \
# 0                 0.000                     NaN            0.000
# 1                 0.000                     NaN            0.000
# 2                 0.000                     NaN            0.000
# 3                 0.000                     NaN            0.000
# 4                 0.000                     NaN            0.000
# ...                 ...                     ...              ...
# 23190             0.000                     NaN            0.000
# 23191             0.000                     NaN            0.000
# 23192             0.000                     NaN            0.000
# 23193             0.000                     NaN            0.000
# 23194               NaN                     NaN              NaN
#
#        wind_share_energy
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 23190                NaN
# 23191                NaN
# 23192                NaN
# 23193                NaN
# 23194                NaN
#
# [23195 rows x 130 columns]

# %%
countries = df_energy['country'].unique()
countries_count = len(countries)
countries_count
# Out:
# 314

# %% [markdown]
# 314 unique countries counted within dataset.

# %%
df_energy = df_energy.groupby(['country', 'year']).agg('sum').reset_index()
df_energy
# Out:
#              country  year iso_code   population             gdp  \
# 0      ASEAN (Ember)  2000        0        0.000           0.000
# 1      ASEAN (Ember)  2001        0        0.000           0.000
# 2      ASEAN (Ember)  2002        0        0.000           0.000
# 3      ASEAN (Ember)  2003        0        0.000           0.000
# 4      ASEAN (Ember)  2004        0        0.000           0.000
# ...              ...   ...      ...          ...             ...
# 23190       Zimbabwe  2020      ZWE 15526837.000 23178706944.000
# 23191       Zimbabwe  2021      ZWE 15797165.000 25140088832.000
# 23192       Zimbabwe  2022      ZWE 16069010.000 25901586432.000
# 23193       Zimbabwe  2023      ZWE 16340778.000           0.000
# 23194       Zimbabwe  2024      ZWE 16634317.000           0.000
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 0                        0.000                    0.000
# 1                        0.000                    0.000
# 2                        0.000                    0.000
# 3                        0.000                    0.000
# 4                        0.000                    0.000
# ...                        ...                      ...
# 23190                    0.000                    0.000
# 23191                    0.000                    0.000
# 23192                    0.000                    0.000
# 23193                    0.000                    0.000
# 23194                    0.000                    0.000
#
#        biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 0                        0.000                0.000                    0.000
# 1                        0.000                0.000                    0.000
# 2                        0.000                0.000                    0.000
# 3                        0.000                0.000                    0.000
# 4                        0.000                0.000                    0.000
# ...                        ...                  ...                      ...
# 23190                    0.000                0.000                    6.440
# 23191                    0.000                0.000                    6.963
# 23192                    0.000                0.000                    6.845
# 23193                    0.000                0.000                    7.344
# 23194                    0.000                0.000                    0.000
#
#        ...  solar_share_elec  solar_share_energy  wind_cons_change_pct  \
# 0      ...             0.000               0.000                 0.000
# 1      ...             0.000               0.000                 0.000
# 2      ...             0.000               0.000                 0.000
# 3      ...             0.000               0.000                 0.000
# 4      ...             0.000               0.000                 0.000
# ...    ...               ...                 ...                   ...
# 23190  ...             0.298               0.000                 0.000
# 23191  ...             0.233               0.000                 0.000
# 23192  ...             0.336               0.000                 0.000
# 23193  ...             0.361               0.000                 0.000
# 23194  ...             0.000               0.000                 0.000
#
#        wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 0                     0.000             0.000                 0.000
# 1                     0.000             0.000                 0.000
# 2                     0.000             0.000                 0.000
# 3                     0.000             0.000                 0.000
# 4                     0.000             0.000                 0.000
# ...                     ...               ...                   ...
# 23190                 0.000             0.000                 0.000
# 23191                 0.000             0.000                 0.000
# 23192                 0.000             0.000                 0.000
# 23193                 0.000             0.000                 0.000
# 23194                 0.000             0.000                 0.000
#
#        wind_electricity  wind_energy_per_capita  wind_share_elec  \
# 0                 0.000                   0.000            0.000
# 1                 0.000                   0.000            0.000
# 2                 0.000                   0.000            0.000
# 3                 0.000                   0.000            0.000
# 4                 0.000                   0.000            0.000
# ...                 ...                     ...              ...
# 23190             0.000                   0.000            0.000
# 23191             0.000                   0.000            0.000
# 23192             0.000                   0.000            0.000
# 23193             0.000                   0.000            0.000
# 23194             0.000                   0.000            0.000
#
#        wind_share_energy
# 0                  0.000
# 1                  0.000
# 2                  0.000
# 3                  0.000
# 4                  0.000
# ...                  ...
# 23190              0.000
# 23191              0.000
# 23192              0.000
# 23193              0.000
# 23194              0.000
#
# [23195 rows x 130 columns]

# %%
# Count of how many times each year is covered
year_counts = df_energy['year'].value_counts()
year_counts
# Out:
# year
# 2005    308
# 2012    308
# 2015    308
# 2014    308
# 2013    308
#        ...
# 1940    118
# 1936    118
# 1949    118
# 1950    118
# 1951    118
# Name: count, Length: 125, dtype: int64

# %%
# List which years appear 308 times
years_308 = year_counts[year_counts == 308].index.tolist()
print(f"All years appearing 308 times: {years_308}")
# Out:
# All years appearing 308 times: [2005, 2012, 2015, 2014, 2013, 2016]

# %%
# Drop years that are not between 1994 and 2023, as done with dataset 1 in preparation for enrichment
df_energy = df_energy[(df_energy['year'] >= 1994) & (df_energy['year'] <= 2023)]
df_energy
# Out:
#              country  year iso_code   population             gdp  \
# 0      ASEAN (Ember)  2000        0        0.000           0.000
# 1      ASEAN (Ember)  2001        0        0.000           0.000
# 2      ASEAN (Ember)  2002        0        0.000           0.000
# 3      ASEAN (Ember)  2003        0        0.000           0.000
# 4      ASEAN (Ember)  2004        0        0.000           0.000
# ...              ...   ...      ...          ...             ...
# 23189       Zimbabwe  2019      ZWE 15271330.000 25146417152.000
# 23190       Zimbabwe  2020      ZWE 15526837.000 23178706944.000
# 23191       Zimbabwe  2021      ZWE 15797165.000 25140088832.000
# 23192       Zimbabwe  2022      ZWE 16069010.000 25901586432.000
# 23193       Zimbabwe  2023      ZWE 16340778.000           0.000
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 0                        0.000                    0.000
# 1                        0.000                    0.000
# 2                        0.000                    0.000
# 3                        0.000                    0.000
# 4                        0.000                    0.000
# ...                        ...                      ...
# 23189                    0.000                    0.000
# 23190                    0.000                    0.000
# 23191                    0.000                    0.000
# 23192                    0.000                    0.000
# 23193                    0.000                    0.000
#
#        biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 0                        0.000                0.000                    0.000
# 1                        0.000                0.000                    0.000
# 2                        0.000                0.000                    0.000
# 3                        0.000                0.000                    0.000
# 4                        0.000                0.000                    0.000
# ...                        ...                  ...                      ...
# 23189                    0.000                0.000                   12.442
# 23190                    0.000                0.000                    6.440
# 23191                    0.000                0.000                    6.963
# 23192                    0.000                0.000                    6.845
# 23193                    0.000                0.000                    7.344
#
#        ...  solar_share_elec  solar_share_energy  wind_cons_change_pct  \
# 0      ...             0.000               0.000                 0.000
# 1      ...             0.000               0.000                 0.000
# 2      ...             0.000               0.000                 0.000
# 3      ...             0.000               0.000                 0.000
# 4      ...             0.000               0.000                 0.000
# ...    ...               ...                 ...                   ...
# 23189  ...             0.236               0.000                 0.000
# 23190  ...             0.298               0.000                 0.000
# 23191  ...             0.233               0.000                 0.000
# 23192  ...             0.336               0.000                 0.000
# 23193  ...             0.361               0.000                 0.000
#
#        wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 0                     0.000             0.000                 0.000
# 1                     0.000             0.000                 0.000
# 2                     0.000             0.000                 0.000
# 3                     0.000             0.000                 0.000
# 4                     0.000             0.000                 0.000
# ...                     ...               ...                   ...
# 23189                 0.000             0.000                 0.000
# 23190                 0.000             0.000                 0.000
# 23191                 0.000             0.000                 0.000
# 23192                 0.000             0.000                 0.000
# 23193                 0.000             0.000                 0.000
#
#        wind_electricity  wind_energy_per_capita  wind_share_elec  \
# 0                 0.000                   0.000            0.000
# 1                 0.000                   0.000            0.000
# 2                 0.000                   0.000            0.000
# 3                 0.000                   0.000            0.000
# 4                 0.000                   0.000            0.000
# ...                 ...                     ...              ...
# 23189             0.000                   0.000            0.000
# 23190             0.000                   0.000            0.000
# 23191             0.000                   0.000            0.000
# 23192             0.000                   0.000            0.000
# 23193             0.000                   0.000            0.000
#
#        wind_share_energy
# 0                  0.000
# 1                  0.000
# 2                  0.000
# 3                  0.000
# 4                  0.000
# ...                  ...
# 23189              0.000
# 23190              0.000
# 23191              0.000
# 23192              0.000
# 23193              0.000
#
# [9036 rows x 130 columns]

# %% [markdown]
# Records dropped from 23195 to 9036

# %% [markdown]
# ### Nulls

# %%
# Calculate the percentage of null values in each column
nulls_energy = pd.Series(null_percentage(df_energy))
# Due to dropping rows, nulls are now set to 0.0
nulls_energy = pd.Series(count_zeros(df_energy))
nulls_energy
# Out:
# country                   0.000
# year                      0.000
# iso_code                 27.413
# population               23.506
# gdp                      47.089
#                           ...
# wind_elec_per_capita     74.259
# wind_electricity         65.173
# wind_energy_per_capita   78.066
# wind_share_elec          65.250
# wind_share_energy        73.141
# Length: 130, dtype: float64

# %%
# Display rows with iso codes that are equal to 0
df_energy[df_energy['iso_code'] == 0]
# Out:
#              country  year iso_code     population                 gdp  \
# 0      ASEAN (Ember)  2000        0          0.000               0.000
# 1      ASEAN (Ember)  2001        0          0.000               0.000
# 2      ASEAN (Ember)  2002        0          0.000               0.000
# 3      ASEAN (Ember)  2003        0          0.000               0.000
# 4      ASEAN (Ember)  2004        0          0.000               0.000
# ...              ...   ...      ...            ...                 ...
# 22802          World  2019        0 7811293646.000 122149364826112.000
# 22803          World  2020        0 7887001253.000 118590019731456.000
# 22804          World  2021        0 7954448327.000 126004794228736.000
# 22805          World  2022        0 8021407128.000 130112561348608.000
# 22806          World  2023        0 8091734853.000               0.000
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 0                        0.000                    0.000
# 1                        0.000                    0.000
# 2                        0.000                    0.000
# 3                        0.000                    0.000
# 4                        0.000                    0.000
# ...                        ...                      ...
# 22802                    8.519                   88.498
# 22803                   -5.241                  -59.084
# 22804                    5.606                   59.890
# 22805                    5.763                   65.012
# 22806                   10.568                  126.085
#
#        biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 0                        0.000                0.000                    0.000
# 1                        0.000                0.000                    0.000
# 2                        0.000                0.000                    0.000
# 3                        0.000                0.000                    0.000
# 4                        0.000                0.000                    0.000
# ...                        ...                  ...                      ...
# 22802                  144.318             1127.314                   74.143
# 22803                  135.442             1068.230                   78.003
# 22804                  141.822             1128.119                   84.138
# 22805                  148.743             1193.131                   85.375
# 22806                  163.033             1319.216                   85.404
#
#        ...  solar_share_elec  solar_share_energy  wind_cons_change_pct  \
# 0      ...             0.000               0.000                 0.000
# 1      ...             0.000               0.000                 0.000
# 2      ...             0.000               0.000                 0.000
# 3      ...             0.000               0.000                 0.000
# 4      ...             0.000               0.000                 0.000
# ...    ...               ...                 ...                   ...
# 22802  ...             2.623               1.076                11.884
# 22803  ...             3.198               1.350                12.199
# 22804  ...             3.726               1.573                16.597
# 22805  ...             4.597               1.937                13.411
# 22806  ...             5.581               2.357                10.075
#
#        wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 0                     0.000             0.000                 0.000
# 1                     0.000             0.000                 0.000
# 2                     0.000             0.000                 0.000
# 3                     0.000             0.000                 0.000
# 4                     0.000             0.000                 0.000
# ...                     ...               ...                   ...
# 22802               358.285          3520.444               181.890
# 22803               419.721          3940.165               201.771
# 22804               642.617          4582.781               233.410
# 22805               601.820          5184.602               262.663
# 22806               480.606          5665.208               285.740
#
#        wind_electricity  wind_energy_per_capita  wind_share_elec  \
# 0                 0.000                   0.000            0.000
# 1                 0.000                   0.000            0.000
# 2                 0.000                   0.000            0.000
# 3                 0.000                   0.000            0.000
# 4                 0.000                   0.000            0.000
# ...                 ...                     ...              ...
# 22802          1420.800                 450.686            5.291
# 22803          1591.370                 499.577            5.951
# 22804          1856.650                 576.128            6.567
# 22805          2106.930                 646.346            7.284
# 22806          2312.130                 700.123            7.789
#
#        wind_share_energy
# 0                  0.000
# 1                  0.000
# 2                  0.000
# 3                  0.000
# 4                  0.000
# ...                  ...
# 22802              2.166
# 22803              2.513
# 22804              2.781
# 22805              3.090
# 22806              3.317
#
# [2477 rows x 130 columns]

# %%
# Display countries that have iso codes equal to 0
df_energy[df_energy['iso_code'] == 0]['country'].unique()
# Out:
# array(['ASEAN (Ember)', 'Africa', 'Africa (EI)', 'Africa (EIA)',
#        'Africa (Ember)', 'Africa (Shift)', 'Asia', 'Asia & Oceania (EIA)',
#        'Asia (Ember)', 'Asia Pacific (EI)', 'Asia and Oceania (Shift)',
#        'Australia and New Zealand (EIA)', 'CIS (EI)',
#        'Central & South America (EIA)', 'Central America (EI)',
#        'Central and South America (Shift)', 'EU (Ember)', 'EU28 (Shift)',
#        'Eastern Africa (EI)', 'Eastern Europe and Eurasia (EIA)',
#        'Eurasia (EIA)', 'Eurasia (Shift)', 'Europe', 'Europe (EI)',
#        'Europe (EIA)', 'Europe (Ember)', 'Europe (Shift)',
#        'European Union (27)', 'G20 (Ember)', 'G7 (Ember)',
#        'High-income countries', 'Kosovo',
#        'Latin America and Caribbean (Ember)', 'Low-income countries',
#        'Lower-middle-income countries', 'Middle Africa (EI)',
#        'Middle East (EI)', 'Middle East (EIA)', 'Middle East (Ember)',
#        'Middle East (Shift)', 'Non-OECD (EI)', 'Non-OECD (EIA)',
#        'Non-OPEC (EI)', 'Non-OPEC (EIA)', 'North America',
#        'North America (EI)', 'North America (Ember)',
#        'North America (Shift)', 'OECD (EI)', 'OECD (EIA)', 'OECD (Ember)',
#        'OECD (Shift)', 'OPEC (EI)', 'OPEC (EIA)', 'OPEC (Shift)',
#        'Oceania', 'Oceania (Ember)', 'Other Africa (EI)',
#        'Other Americas (EIA)', 'Other Asia Pacific (EI)',
#        'Other Asia-Pacific (EIA)', 'Other CIS (EI)',
#        'Other Caribbean (EI)', 'Other Eastern Africa (EI)',
#        'Other Europe (EI)', 'Other Middle Africa (EI)',
#        'Other Middle East (EI)', 'Other North America (EI)',
#        'Other Northern Africa (EI)', 'Other South America (EI)',
#        'Other South and Central America (EI)',
#        'Other Southern Africa (EI)', 'Other Western Africa (EI)',
#        'Persian Gulf (EIA)', 'Persian Gulf (Shift)', 'Rest of World (EI)',
#        'Serbia and Montenegro', 'South America',
#        'South and Central America (EI)', 'U.S. Pacific Islands (EIA)',
#        'U.S. Territories (EIA)', 'United States Pacific Islands (Shift)',
#        'United States Territories (Shift)',
#        'Upper-middle-income countries', 'Wake Island (EIA)',
#        'Wake Island (Shift)', 'Western Africa (EI)',
#        'Western Europe (EIA)', 'World'], dtype=object)

# %% [markdown]
# Countries are aggregated without iso codes. Removing rows with iso codes equal to 0.

# %%
df_energy = df_energy[df_energy['iso_code'] != 0].reset_index(drop=True)
df_energy
# Out:
#           country  year iso_code   population             gdp  \
# 0     Afghanistan  1994      AFG 16250755.000  7919856640.000
# 1     Afghanistan  1995      AFG 17065794.000 12307525632.000
# 2     Afghanistan  1996      AFG 17763221.000 12070125568.000
# 3     Afghanistan  1997      AFG 18452049.000 11850753024.000
# 4     Afghanistan  1998      AFG 19159955.000 11692171264.000
# ...           ...   ...      ...          ...             ...
# 6554     Zimbabwe  2019      ZWE 15271330.000 25146417152.000
# 6555     Zimbabwe  2020      ZWE 15526837.000 23178706944.000
# 6556     Zimbabwe  2021      ZWE 15797165.000 25140088832.000
# 6557     Zimbabwe  2022      ZWE 16069010.000 25901586432.000
# 6558     Zimbabwe  2023      ZWE 16340778.000           0.000
#
#       biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 0                       0.000                    0.000
# 1                       0.000                    0.000
# 2                       0.000                    0.000
# 3                       0.000                    0.000
# 4                       0.000                    0.000
# ...                       ...                      ...
# 6554                    0.000                    0.000
# 6555                    0.000                    0.000
# 6556                    0.000                    0.000
# 6557                    0.000                    0.000
# 6558                    0.000                    0.000
#
#       biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 0                       0.000                0.000                    0.000
# 1                       0.000                0.000                    0.000
# 2                       0.000                0.000                    0.000
# 3                       0.000                0.000                    0.000
# 4                       0.000                0.000                    0.000
# ...                       ...                  ...                      ...
# 6554                    0.000                0.000                   12.442
# 6555                    0.000                0.000                    6.440
# 6556                    0.000                0.000                    6.963
# 6557                    0.000                0.000                    6.845
# 6558                    0.000                0.000                    7.344
#
#       ...  solar_share_elec  solar_share_energy  wind_cons_change_pct  \
# 0     ...             0.000               0.000                 0.000
# 1     ...             0.000               0.000                 0.000
# 2     ...             0.000               0.000                 0.000
# 3     ...             0.000               0.000                 0.000
# 4     ...             0.000               0.000                 0.000
# ...   ...               ...                 ...                   ...
# 6554  ...             0.236               0.000                 0.000
# 6555  ...             0.298               0.000                 0.000
# 6556  ...             0.233               0.000                 0.000
# 6557  ...             0.336               0.000                 0.000
# 6558  ...             0.361               0.000                 0.000
#
#       wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 0                    0.000             0.000                 0.000
# 1                    0.000             0.000                 0.000
# 2                    0.000             0.000                 0.000
# 3                    0.000             0.000                 0.000
# 4                    0.000             0.000                 0.000
# ...                    ...               ...                   ...
# 6554                 0.000             0.000                 0.000
# 6555                 0.000             0.000                 0.000
# 6556                 0.000             0.000                 0.000
# 6557                 0.000             0.000                 0.000
# 6558                 0.000             0.000                 0.000
#
#       wind_electricity  wind_energy_per_capita  wind_share_elec  \
# 0                0.000                   0.000            0.000
# 1                0.000                   0.000            0.000
# 2                0.000                   0.000            0.000
# 3                0.000                   0.000            0.000
# 4                0.000                   0.000            0.000
# ...                ...                     ...              ...
# 6554             0.000                   0.000            0.000
# 6555             0.000                   0.000            0.000
# 6556             0.000                   0.000            0.000
# 6557             0.000                   0.000            0.000
# 6558             0.000                   0.000            0.000
#
#       wind_share_energy
# 0                 0.000
# 1                 0.000
# 2                 0.000
# 3                 0.000
# 4                 0.000
# ...                 ...
# 6554              0.000
# 6555              0.000
# 6556              0.000
# 6557              0.000
# 6558              0.000
#
# [6559 rows x 130 columns]

# %%
# Display new count zero percentages
nulls_energy = pd.Series(count_zeros(df_energy))
nulls_energy
# Out:
# country                   0.000
# year                      0.000
# iso_code                  0.000
# population                0.656
# gdp                      27.260
#                           ...
# wind_elec_per_capita     69.812
# wind_electricity         69.843
# wind_energy_per_capita   74.783
# wind_share_elec          69.904
# wind_share_energy        75.728
# Length: 130, dtype: float64

# %%
# Display records where population is zero
df_energy[df_energy['population'] == 0]
# Out:
#                    country  year iso_code  population   gdp  \
# 150             Antarctica  1994      ATA       0.000 0.000
# 151             Antarctica  1995      ATA       0.000 0.000
# 152             Antarctica  1996      ATA       0.000 0.000
# 153             Antarctica  1997      ATA       0.000 0.000
# 154             Antarctica  1998      ATA       0.000 0.000
# 155             Antarctica  1999      ATA       0.000 0.000
# 156             Antarctica  2000      ATA       0.000 0.000
# 157             Antarctica  2001      ATA       0.000 0.000
# 158             Antarctica  2002      ATA       0.000 0.000
# 159             Antarctica  2003      ATA       0.000 0.000
# 160             Antarctica  2004      ATA       0.000 0.000
# 161             Antarctica  2005      ATA       0.000 0.000
# 162             Antarctica  2006      ATA       0.000 0.000
# 163             Antarctica  2007      ATA       0.000 0.000
# 164             Antarctica  2008      ATA       0.000 0.000
# 165             Antarctica  2009      ATA       0.000 0.000
# 166             Antarctica  2010      ATA       0.000 0.000
# 167             Antarctica  2011      ATA       0.000 0.000
# 168             Antarctica  2012      ATA       0.000 0.000
# 169             Antarctica  2013      ATA       0.000 0.000
# 170             Antarctica  2014      ATA       0.000 0.000
# 171             Antarctica  2015      ATA       0.000 0.000
# 172             Antarctica  2016      ATA       0.000 0.000
# 173             Antarctica  2017      ATA       0.000 0.000
# 174             Antarctica  2018      ATA       0.000 0.000
# 175             Antarctica  2019      ATA       0.000 0.000
# 176             Antarctica  2020      ATA       0.000 0.000
# 177             Antarctica  2021      ATA       0.000 0.000
# 178             Antarctica  2022      ATA       0.000 0.000
# 179             Antarctica  2023      ATA       0.000 0.000
# 4167  Netherlands Antilles  2011      ANT       0.000 0.000
# 4168  Netherlands Antilles  2012      ANT       0.000 0.000
# 4169  Netherlands Antilles  2013      ANT       0.000 0.000
# 4170  Netherlands Antilles  2014      ANT       0.000 0.000
# 4171  Netherlands Antilles  2015      ANT       0.000 0.000
# 4172  Netherlands Antilles  2016      ANT       0.000 0.000
# 4173  Netherlands Antilles  2017      ANT       0.000 0.000
# 4174  Netherlands Antilles  2018      ANT       0.000 0.000
# 4175  Netherlands Antilles  2019      ANT       0.000 0.000
# 4176  Netherlands Antilles  2020      ANT       0.000 0.000
# 4177  Netherlands Antilles  2021      ANT       0.000 0.000
# 4178  Netherlands Antilles  2022      ANT       0.000 0.000
# 4179  Netherlands Antilles  2023      ANT       0.000 0.000
#
#       biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 150                     0.000                    0.000
# 151                     0.000                    0.000
# 152                     0.000                    0.000
# 153                     0.000                    0.000
# 154                     0.000                    0.000
# 155                     0.000                    0.000
# 156                     0.000                    0.000
# 157                     0.000                    0.000
# 158                     0.000                    0.000
# 159                     0.000                    0.000
# 160                     0.000                    0.000
# 161                     0.000                    0.000
# 162                     0.000                    0.000
# 163                     0.000                    0.000
# 164                     0.000                    0.000
# 165                     0.000                    0.000
# 166                     0.000                    0.000
# 167                     0.000                    0.000
# 168                     0.000                    0.000
# 169                     0.000                    0.000
# 170                     0.000                    0.000
# 171                     0.000                    0.000
# 172                     0.000                    0.000
# 173                     0.000                    0.000
# 174                     0.000                    0.000
# 175                     0.000                    0.000
# 176                     0.000                    0.000
# 177                     0.000                    0.000
# 178                     0.000                    0.000
# 179                     0.000                    0.000
# 4167                    0.000                    0.000
# 4168                    0.000                    0.000
# 4169                    0.000                    0.000
# 4170                    0.000                    0.000
# 4171                    0.000                    0.000
# 4172                    0.000                    0.000
# 4173                    0.000                    0.000
# 4174                    0.000                    0.000
# 4175                    0.000                    0.000
# 4176                    0.000                    0.000
# 4177                    0.000                    0.000
# 4178                    0.000                    0.000
# 4179                    0.000                    0.000
#
#       biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 150                     0.000                0.000                    0.000
# 151                     0.000                0.000                    0.000
# 152                     0.000                0.000                    0.000
# 153                     0.000                0.000                    0.000
# 154                     0.000                0.000                    0.000
# 155                     0.000                0.000                    0.000
# 156                     0.000                0.000                    0.000
# 157                     0.000                0.000                    0.000
# 158                     0.000                0.000                    0.000
# 159                     0.000                0.000                    0.000
# 160                     0.000                0.000                    0.000
# 161                     0.000                0.000                    0.000
# 162                     0.000                0.000                    0.000
# 163                     0.000                0.000                    0.000
# 164                     0.000                0.000                    0.000
# 165                     0.000                0.000                    0.000
# 166                     0.000                0.000                    0.000
# 167                     0.000                0.000                    0.000
# 168                     0.000                0.000                    0.000
# 169                     0.000                0.000                    0.000
# 170                     0.000                0.000                    0.000
# 171                     0.000                0.000                    0.000
# 172                     0.000                0.000                    0.000
# 173                     0.000                0.000                    0.000
# 174                     0.000                0.000                    0.000
# 175                     0.000                0.000                    0.000
# 176                     0.000                0.000                    0.000
# 177                     0.000                0.000                    0.000
# 178                     0.000                0.000                    0.000
# 179                     0.000                0.000                    0.000
# 4167                    0.000                0.000                    0.000
# 4168                    0.000                0.000                    0.000
# 4169                    0.000                0.000                    0.000
# 4170                    0.000                0.000                    0.000
# 4171                    0.000                0.000                    0.000
# 4172                    0.000                0.000                    0.000
# 4173                    0.000                0.000                    0.000
# 4174                    0.000                0.000                    0.000
# 4175                    0.000                0.000                    0.000
# 4176                    0.000                0.000                    0.000
# 4177                    0.000                0.000                    0.000
# 4178                    0.000                0.000                    0.000
# 4179                    0.000                0.000                    0.000
#
#       ...  solar_share_elec  solar_share_energy  wind_cons_change_pct  \
# 150   ...             0.000               0.000                 0.000
# 151   ...             0.000               0.000                 0.000
# 152   ...             0.000               0.000                 0.000
# 153   ...             0.000               0.000                 0.000
# 154   ...             0.000               0.000                 0.000
# 155   ...             0.000               0.000                 0.000
# 156   ...             0.000               0.000                 0.000
# 157   ...             0.000               0.000                 0.000
# 158   ...             0.000               0.000                 0.000
# 159   ...             0.000               0.000                 0.000
# 160   ...             0.000               0.000                 0.000
# 161   ...             0.000               0.000                 0.000
# 162   ...             0.000               0.000                 0.000
# 163   ...             0.000               0.000                 0.000
# 164   ...             0.000               0.000                 0.000
# 165   ...             0.000               0.000                 0.000
# 166   ...             0.000               0.000                 0.000
# 167   ...             0.000               0.000                 0.000
# 168   ...             0.000               0.000                 0.000
# 169   ...             0.000               0.000                 0.000
# 170   ...             0.000               0.000                 0.000
# 171   ...             0.000               0.000                 0.000
# 172   ...             0.000               0.000                 0.000
# 173   ...             0.000               0.000                 0.000
# 174   ...             0.000               0.000                 0.000
# 175   ...             0.000               0.000                 0.000
# 176   ...             0.000               0.000                 0.000
# 177   ...             0.000               0.000                 0.000
# 178   ...             0.000               0.000                 0.000
# 179   ...             0.000               0.000                 0.000
# 4167  ...             0.000               0.000                 0.000
# 4168  ...             0.000               0.000                 0.000
# 4169  ...             0.000               0.000                 0.000
# 4170  ...             0.000               0.000                 0.000
# 4171  ...             0.000               0.000                 0.000
# 4172  ...             0.000               0.000                 0.000
# 4173  ...             0.000               0.000                 0.000
# 4174  ...             0.000               0.000                 0.000
# 4175  ...             0.000               0.000                 0.000
# 4176  ...             0.000               0.000                 0.000
# 4177  ...             0.000               0.000                 0.000
# 4178  ...             0.000               0.000                 0.000
# 4179  ...             0.000               0.000                 0.000
#
#       wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 150                  0.000             0.000                 0.000
# 151                  0.000             0.000                 0.000
# 152                  0.000             0.000                 0.000
# 153                  0.000             0.000                 0.000
# 154                  0.000             0.000                 0.000
# 155                  0.000             0.000                 0.000
# 156                  0.000             0.000                 0.000
# 157                  0.000             0.000                 0.000
# 158                  0.000             0.000                 0.000
# 159                  0.000             0.000                 0.000
# 160                  0.000             0.000                 0.000
# 161                  0.000             0.000                 0.000
# 162                  0.000             0.000                 0.000
# 163                  0.000             0.000                 0.000
# 164                  0.000             0.000                 0.000
# 165                  0.000             0.000                 0.000
# 166                  0.000             0.000                 0.000
# 167                  0.000             0.000                 0.000
# 168                  0.000             0.000                 0.000
# 169                  0.000             0.000                 0.000
# 170                  0.000             0.000                 0.000
# 171                  0.000             0.000                 0.000
# 172                  0.000             0.000                 0.000
# 173                  0.000             0.000                 0.000
# 174                  0.000             0.000                 0.000
# 175                  0.000             0.000                 0.000
# 176                  0.000             0.000                 0.000
# 177                  0.000             0.000                 0.000
# 178                  0.000             0.000                 0.000
# 179                  0.000             0.000                 0.000
# 4167                 0.000             0.000                 0.000
# 4168                 0.000             0.000                 0.000
# 4169                 0.000             0.000                 0.000
# 4170                 0.000             0.000                 0.000
# 4171                 0.000             0.000                 0.000
# 4172                 0.000             0.000                 0.000
# 4173                 0.000             0.000                 0.000
# 4174                 0.000             0.000                 0.000
# 4175                 0.000             0.000                 0.000
# 4176                 0.000             0.000                 0.000
# 4177                 0.000             0.000                 0.000
# 4178                 0.000             0.000                 0.000
# 4179                 0.000             0.000                 0.000
#
#       wind_electricity  wind_energy_per_capita  wind_share_elec  \
# 150              0.000                   0.000            0.000
# 151              0.000                   0.000            0.000
# 152              0.000                   0.000            0.000
# 153              0.000                   0.000            0.000
# 154              0.000                   0.000            0.000
# 155              0.000                   0.000            0.000
# 156              0.000                   0.000            0.000
# 157              0.000                   0.000            0.000
# 158              0.000                   0.000            0.000
# 159              0.000                   0.000            0.000
# 160              0.000                   0.000            0.000
# 161              0.000                   0.000            0.000
# 162              0.000                   0.000            0.000
# 163              0.000                   0.000            0.000
# 164              0.000                   0.000            0.000
# 165              0.000                   0.000            0.000
# 166              0.000                   0.000            0.000
# 167              0.000                   0.000            0.000
# 168              0.000                   0.000            0.000
# 169              0.000                   0.000            0.000
# 170              0.000                   0.000            0.000
# 171              0.000                   0.000            0.000
# 172              0.000                   0.000            0.000
# 173              0.000                   0.000            0.000
# 174              0.000                   0.000            0.000
# 175              0.000                   0.000            0.000
# 176              0.000                   0.000            0.000
# 177              0.000                   0.000            0.000
# 178              0.000                   0.000            0.000
# 179              0.000                   0.000            0.000
# 4167             0.000                   0.000            0.000
# 4168             0.000                   0.000            0.000
# 4169             0.000                   0.000            0.000
# 4170             0.000                   0.000            0.000
# 4171             0.000                   0.000            0.000
# 4172             0.000                   0.000            0.000
# 4173             0.000                   0.000            0.000
# 4174             0.000                   0.000            0.000
# 4175             0.000                   0.000            0.000
# 4176             0.000                   0.000            0.000
# 4177             0.000                   0.000            0.000
# 4178             0.000                   0.000            0.000
# 4179             0.000                   0.000            0.000
#
#       wind_share_energy
# 150               0.000
# 151               0.000
# 152               0.000
# 153               0.000
# 154               0.000
# 155               0.000
# 156               0.000
# 157               0.000
# 158               0.000
# 159               0.000
# 160               0.000
# 161               0.000
# 162               0.000
# 163               0.000
# 164               0.000
# 165               0.000
# 166               0.000
# 167               0.000
# 168               0.000
# 169               0.000
# 170               0.000
# 171               0.000
# 172               0.000
# 173               0.000
# 174               0.000
# 175               0.000
# 176               0.000
# 177               0.000
# 178               0.000
# 179               0.000
# 4167              0.000
# 4168              0.000
# 4169              0.000
# 4170              0.000
# 4171              0.000
# 4172              0.000
# 4173              0.000
# 4174              0.000
# 4175              0.000
# 4176              0.000
# 4177              0.000
# 4178              0.000
# 4179              0.000
#
# [43 rows x 130 columns]

# %%
# Drop records where population is zero
df_energy = df_energy[df_energy['population'] != 0].reset_index(drop=True)
df_energy
# Out:
#           country  year iso_code   population             gdp  \
# 0     Afghanistan  1994      AFG 16250755.000  7919856640.000
# 1     Afghanistan  1995      AFG 17065794.000 12307525632.000
# 2     Afghanistan  1996      AFG 17763221.000 12070125568.000
# 3     Afghanistan  1997      AFG 18452049.000 11850753024.000
# 4     Afghanistan  1998      AFG 19159955.000 11692171264.000
# ...           ...   ...      ...          ...             ...
# 6511     Zimbabwe  2019      ZWE 15271330.000 25146417152.000
# 6512     Zimbabwe  2020      ZWE 15526837.000 23178706944.000
# 6513     Zimbabwe  2021      ZWE 15797165.000 25140088832.000
# 6514     Zimbabwe  2022      ZWE 16069010.000 25901586432.000
# 6515     Zimbabwe  2023      ZWE 16340778.000           0.000
#
#       biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 0                       0.000                    0.000
# 1                       0.000                    0.000
# 2                       0.000                    0.000
# 3                       0.000                    0.000
# 4                       0.000                    0.000
# ...                       ...                      ...
# 6511                    0.000                    0.000
# 6512                    0.000                    0.000
# 6513                    0.000                    0.000
# 6514                    0.000                    0.000
# 6515                    0.000                    0.000
#
#       biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 0                       0.000                0.000                    0.000
# 1                       0.000                0.000                    0.000
# 2                       0.000                0.000                    0.000
# 3                       0.000                0.000                    0.000
# 4                       0.000                0.000                    0.000
# ...                       ...                  ...                      ...
# 6511                    0.000                0.000                   12.442
# 6512                    0.000                0.000                    6.440
# 6513                    0.000                0.000                    6.963
# 6514                    0.000                0.000                    6.845
# 6515                    0.000                0.000                    7.344
#
#       ...  solar_share_elec  solar_share_energy  wind_cons_change_pct  \
# 0     ...             0.000               0.000                 0.000
# 1     ...             0.000               0.000                 0.000
# 2     ...             0.000               0.000                 0.000
# 3     ...             0.000               0.000                 0.000
# 4     ...             0.000               0.000                 0.000
# ...   ...               ...                 ...                   ...
# 6511  ...             0.236               0.000                 0.000
# 6512  ...             0.298               0.000                 0.000
# 6513  ...             0.233               0.000                 0.000
# 6514  ...             0.336               0.000                 0.000
# 6515  ...             0.361               0.000                 0.000
#
#       wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 0                    0.000             0.000                 0.000
# 1                    0.000             0.000                 0.000
# 2                    0.000             0.000                 0.000
# 3                    0.000             0.000                 0.000
# 4                    0.000             0.000                 0.000
# ...                    ...               ...                   ...
# 6511                 0.000             0.000                 0.000
# 6512                 0.000             0.000                 0.000
# 6513                 0.000             0.000                 0.000
# 6514                 0.000             0.000                 0.000
# 6515                 0.000             0.000                 0.000
#
#       wind_electricity  wind_energy_per_capita  wind_share_elec  \
# 0                0.000                   0.000            0.000
# 1                0.000                   0.000            0.000
# 2                0.000                   0.000            0.000
# 3                0.000                   0.000            0.000
# 4                0.000                   0.000            0.000
# ...                ...                     ...              ...
# 6511             0.000                   0.000            0.000
# 6512             0.000                   0.000            0.000
# 6513             0.000                   0.000            0.000
# 6514             0.000                   0.000            0.000
# 6515             0.000                   0.000            0.000
#
#       wind_share_energy
# 0                 0.000
# 1                 0.000
# 2                 0.000
# 3                 0.000
# 4                 0.000
# ...                 ...
# 6511              0.000
# 6512              0.000
# 6513              0.000
# 6514              0.000
# 6515              0.000
#
# [6516 rows x 130 columns]

# %%
# Iso code, population and gdp are shared with dataset one.
# Dropping unnecessary columns to prevent duplication in merge
df_energy = df_energy.drop(columns=['iso_code', 'population', 'gdp'])
df_energy
# Out:
#           country  year  biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 0     Afghanistan  1994                    0.000                    0.000
# 1     Afghanistan  1995                    0.000                    0.000
# 2     Afghanistan  1996                    0.000                    0.000
# 3     Afghanistan  1997                    0.000                    0.000
# 4     Afghanistan  1998                    0.000                    0.000
# ...           ...   ...                      ...                      ...
# 6511     Zimbabwe  2019                    0.000                    0.000
# 6512     Zimbabwe  2020                    0.000                    0.000
# 6513     Zimbabwe  2021                    0.000                    0.000
# 6514     Zimbabwe  2022                    0.000                    0.000
# 6515     Zimbabwe  2023                    0.000                    0.000
#
#       biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 0                       0.000                0.000                    0.000
# 1                       0.000                0.000                    0.000
# 2                       0.000                0.000                    0.000
# 3                       0.000                0.000                    0.000
# 4                       0.000                0.000                    0.000
# ...                       ...                  ...                      ...
# 6511                    0.000                0.000                   12.442
# 6512                    0.000                0.000                    6.440
# 6513                    0.000                0.000                    6.963
# 6514                    0.000                0.000                    6.845
# 6515                    0.000                0.000                    7.344
#
#       biofuel_electricity  biofuel_share_elec  biofuel_share_energy  ...  \
# 0                   0.000               0.000                 0.000  ...
# 1                   0.000               0.000                 0.000  ...
# 2                   0.000               0.000                 0.000  ...
# 3                   0.000               0.000                 0.000  ...
# 4                   0.000               0.000                 0.000  ...
# ...                   ...                 ...                   ...  ...
# 6511                0.190               2.241                 0.000  ...
# 6512                0.100               1.490                 0.000  ...
# 6513                0.110               1.284                 0.000  ...
# 6514                0.110               1.230                 0.000  ...
# 6515                0.120               1.444                 0.000  ...
#
#       solar_share_elec  solar_share_energy  wind_cons_change_pct  \
# 0                0.000               0.000                 0.000
# 1                0.000               0.000                 0.000
# 2                0.000               0.000                 0.000
# 3                0.000               0.000                 0.000
# 4                0.000               0.000                 0.000
# ...                ...                 ...                   ...
# 6511             0.236               0.000                 0.000
# 6512             0.298               0.000                 0.000
# 6513             0.233               0.000                 0.000
# 6514             0.336               0.000                 0.000
# 6515             0.361               0.000                 0.000
#
#       wind_cons_change_twh  wind_consumption  wind_elec_per_capita  \
# 0                    0.000             0.000                 0.000
# 1                    0.000             0.000                 0.000
# 2                    0.000             0.000                 0.000
# 3                    0.000             0.000                 0.000
# 4                    0.000             0.000                 0.000
# ...                    ...               ...                   ...
# 6511                 0.000             0.000                 0.000
# 6512                 0.000             0.000                 0.000
# 6513                 0.000             0.000                 0.000
# 6514                 0.000             0.000                 0.000
# 6515                 0.000             0.000                 0.000
#
#       wind_electricity  wind_energy_per_capita  wind_share_elec  \
# 0                0.000                   0.000            0.000
# 1                0.000                   0.000            0.000
# 2                0.000                   0.000            0.000
# 3                0.000                   0.000            0.000
# 4                0.000                   0.000            0.000
# ...                ...                     ...              ...
# 6511             0.000                   0.000            0.000
# 6512             0.000                   0.000            0.000
# 6513             0.000                   0.000            0.000
# 6514             0.000                   0.000            0.000
# 6515             0.000                   0.000            0.000
#
#       wind_share_energy
# 0                 0.000
# 1                 0.000
# 2                 0.000
# 3                 0.000
# 4                 0.000
# ...                 ...
# 6511              0.000
# 6512              0.000
# 6513              0.000
# 6514              0.000
# 6515              0.000
#
# [6516 rows x 127 columns]

# %%
# Check new null percentages
nulls_energy = pd.Series(count_zeros(df_energy))
nulls_energy.sort_values(ascending=True)
# Out:
# country                                         0.000
# year                                            0.000
# energy_per_capita                               2.901
# primary_energy_consumption                      2.901
# energy_cons_change_pct                          4.972
#                                                 ...
# nuclear_share_energy                           86.050
# nuclear_cons_change_pct                        86.111
# other_renewable_exc_biofuel_electricity        92.265
# other_renewables_elec_per_capita_exc_biofuel   92.265
# other_renewables_share_elec_exc_biofuel        92.265
# Length: 127, dtype: float64

# %% [markdown]
# Dataset consist of 127 columns with large amounts of missing data.
# Prioritize columns with less than 5% missing data for analysis.

# %%
# Return a list of columns with less than 5% missing data
columns_to_keep = nulls_energy[nulls_energy <= 5].index.tolist()
print(f"Columns with less than 5% missing data: {columns_to_keep}")

# Drop columns with more than 5% missing data
df_energy = df_energy[columns_to_keep]
df_energy
# Out:
# Columns with less than 5% missing data: ['country', 'year', 'energy_cons_change_pct', 'energy_per_capita', 'primary_energy_consumption']
#           country  year  energy_cons_change_pct  energy_per_capita  \
# 0     Afghanistan  1994                  -3.487            484.347
# 1     Afghanistan  1995                 -16.202            386.491
# 2     Afghanistan  1996                  -0.651            368.900
# 3     Afghanistan  1997                  -3.917            341.219
# 4     Afghanistan  1998                  -2.232            321.279
# ...           ...   ...                     ...                ...
# 6511     Zimbabwe  2019                  -8.731           2603.889
# 6512     Zimbabwe  2020                 -15.539           2163.075
# 6513     Zimbabwe  2021                  12.059           2382.443
# 6514     Zimbabwe  2022                  55.118           3633.079
# 6515     Zimbabwe  2023                 -10.952           3181.371
#
#       primary_energy_consumption
# 0                          7.871
# 1                          6.596
# 2                          6.553
# 3                          6.296
# 4                          6.156
# ...                          ...
# 6511                      39.765
# 6512                      33.586
# 6513                      37.636
# 6514                      58.380
# 6515                      51.986
#
# [6516 rows x 5 columns]

# %%
# Dropping energy_cons_change_pct column as can be derived from energy_consumption and population
df_energy = df_energy.drop(columns=['energy_cons_change_pct'])
df_energy
# Out:
#           country  year  energy_per_capita  primary_energy_consumption
# 0     Afghanistan  1994            484.347                       7.871
# 1     Afghanistan  1995            386.491                       6.596
# 2     Afghanistan  1996            368.900                       6.553
# 3     Afghanistan  1997            341.219                       6.296
# 4     Afghanistan  1998            321.279                       6.156
# ...           ...   ...                ...                         ...
# 6511     Zimbabwe  2019           2603.889                      39.765
# 6512     Zimbabwe  2020           2163.075                      33.586
# 6513     Zimbabwe  2021           2382.443                      37.636
# 6514     Zimbabwe  2022           3633.079                      58.380
# 6515     Zimbabwe  2023           3181.371                      51.986
#
# [6516 rows x 4 columns]

# %%
# Check new zero values
nulls_energy = pd.Series(count_zeros(df_energy))
nulls_energy
# Out:
# country                      0.000
# year                         0.000
# energy_per_capita            2.901
# primary_energy_consumption   2.901
# dtype: float64

# %%
# Fill values of 0 with the mean of the rest of that column, for numeric columns only
# Fill values of 0 with the mean of the rest of that column, for numeric columns only, grouped by country
numeric_cols = df_energy.select_dtypes(include='number').columns
for col in numeric_cols:
    df_energy[col] = df_energy.groupby('country')[col].transform(lambda x: x.mask(x == 0, x[x != 0].mean()))
df_energy
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6992\29119228.py in ?()
#       1 # Fill values of 0 with the mean of the rest of that column, for numeric columns only
#       2 # Grouped by country
# ----> 3 df_energy = df_energy.groupby('country').apply(lambda x: x.mask(x == 0, x.mean(numeric_only=True), axis=0))
#       4 df_energy.reset_index(drop=True, inplace=True)
#
# c:\Users\MisguidedTree\Desktop\digitalfutures\grant_oglesby_capstone_project\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9186
#    9187         if level is None and by is None:
#    9188             raise TypeError("You have to supply one of 'by' and 'level'")
#    9189
# -> 9190         return DataFrameGroupBy(
#    9191             obj=self,
#    9192             keys=by,
#    9193             axis=axis,
#
# c:\Users\MisguidedTree\Desktop\digitalfutures\grant_oglesby_capstone_project\.venv\Lib\site-packages\pandas\core\groupby\groupby.py in ?(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1326         self.group_keys = group_keys
#    1327         self.dropna = dropna
#    1328
#    1329         if grouper is None:
# -> 1330             grouper, exclusions, obj = get_grouper(
#    1331                 obj,
#    1332                 keys,
#    1333                 axis=axis,
#
# c:\Users\MisguidedTree\Desktop\digitalfutures\grant_oglesby_capstone_project\.venv\Lib\site-packages\pandas\core\groupby\grouper.py in ?(obj, key, axis, level, sort, observed, validate, dropna)
#    1029
#    1030         elif is_in_axis(gpr):  # df.groupby('name')
#    1031             if obj.ndim != 1 and gpr in obj:
#    1032                 if validate:
# -> 1033                     obj._check_label_or_level_ambiguity(gpr, axis=axis)
#    1034                 in_axis, name, gpr = True, gpr, obj[gpr]
#    1035                 if gpr.ndim != 1:
#    1036                     # non-unique columns; raise here to get the name in the
#
# c:\Users\MisguidedTree\Desktop\digitalfutures\grant_oglesby_capstone_project\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1864             msg = (
#    1865                 f"'{key}' is both {level_article} {level_type} level and "
#    1866                 f"{label_article} {label_type} label, which is ambiguous."
#    1867             )
# -> 1868             raise ValueError(msg)
#
# ValueError: 'country' is both an index level and a column label, which is ambiguous.

# %%
# Check for zero values
nulls_energy = pd.Series(count_zeros(df_energy))
nulls_energy
# Out:
# country                      0.000
# year                         0.000
# energy_per_capita            0.000
# primary_energy_consumption   0.000
# dtype: float64

# %% [markdown]
# ## Merge of dataset 1 and dataset 2

# %%
# Merge dataset on index of joint 'country' and 'year'
df_merged = df_co2.merge(df_energy, on=['country', 'year'], how='left')
df_merged
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6992\4213387847.py in ?()
#       1 # Merge dataset on index of joint 'country' and 'year'
# ----> 2 df_merged = df_co2.merge(df_energy, on=['country', 'year'], how='left')
#       3 df_merged
#
# c:\Users\MisguidedTree\Desktop\digitalfutures\grant_oglesby_capstone_project\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10835         validate: MergeValidate | None = None,
#   10836     ) -> DataFrame:
#   10837         from pandas.core.reshape.merge import merge
#   10838
# > 10839         return merge(
#   10840             self,
#   10841             right,
#   10842             how=how,
#
# c:\Users\MisguidedTree\Desktop\digitalfutures\grant_oglesby_capstone_project\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# c:\Users\MisguidedTree\Desktop\digitalfutures\grant_oglesby_capstone_project\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# c:\Users\MisguidedTree\Desktop\digitalfutures\grant_oglesby_capstone_project\.venv\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1294                         # Then we're either Hashable or a wrong-length arraylike,
#    1295                         #  the latter of which will raise
#    1296                         rk = cast(Hashable, rk)
#    1297                         if rk is not None:
# -> 1298                             right_keys.append(right._get_label_or_level_values(rk))
#    1299                         else:
#    1300                             # work-around for merge_asof(right_index=True)
#    1301                             right_keys.append(right.index._values)
#
# c:\Users\MisguidedTree\Desktop\digitalfutures\grant_oglesby_capstone_project\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1902         axis = self._get_axis_number(axis)
#    1903         other_axes = [ax for ax in range(self._AXIS_LEN) if ax != axis]
#    1904
#    1905         if self._is_label_reference(key, axis=axis):
# -> 1906             self._check_label_or_level_ambiguity(key, axis=axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#
# c:\Users\MisguidedTree\Desktop\digitalfutures\grant_oglesby_capstone_project\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1864             msg = (
#    1865                 f"'{key}' is both {level_article} {level_type} level and "
#    1866                 f"{label_article} {label_type} label, which is ambiguous."
#    1867             )
# -> 1868             raise ValueError(msg)
#
# ValueError: 'country' is both an index level and a column label, which is ambiguous.

# %% [markdown]
# Confirmed length of combined table 4920. All records are accounted for.

# %%
# Rearrange so that 'region' appears after 'country'
df_merged = df_merged[['country', 'region'] + [col for col in df_merged.columns if col not in ['country', 'region']]]
df_merged
# Out:
#           country  region  year iso_code  population          gdp    co2  \
# 0     Afghanistan    Asia  1994      AFG    16250799   7919856640  1.454
# 1     Afghanistan    Asia  1995      AFG    17065836  12307525632  1.417
# 2     Afghanistan    Asia  1996      AFG    17763265  12070125568  1.370
# 3     Afghanistan    Asia  1997      AFG    18452100  11850753024  1.304
# 4     Afghanistan    Asia  1998      AFG    19159996  11692171264  1.279
# ...           ...     ...   ...      ...         ...          ...    ...
# 4915     Zimbabwe  Africa  2019      ZWE    15271377  25146417152 10.263
# 4916     Zimbabwe  Africa  2020      ZWE    15526888  23178706944  8.495
# 4917     Zimbabwe  Africa  2021      ZWE    15797220  25140088832 10.204
# 4918     Zimbabwe  Africa  2022      ZWE    16069061  25901586432 10.425
# 4919     Zimbabwe  Africa  2023      ZWE    16340829  23049979833 11.164
#
#       co2_per_capita  cumulative_co2  cumulative_oil_co2  oil_co2  \
# 0              0.089          64.941              33.346    1.032
# 1              0.083          66.358              34.357    1.011
# 2              0.077          67.728              35.343    0.986
# 3              0.071          69.032              36.292    0.949
# 4              0.067          70.311              37.234    0.942
# ...              ...             ...                 ...      ...
# 4915           0.672         774.802             144.767    3.778
# 4916           0.547         783.296             147.830    3.063
# 4917           0.646         793.500             151.565    3.735
# 4918           0.649         803.925             154.944    3.379
# 4919           0.683         815.089             158.306    3.362
#
#       oil_co2_per_capita  energy_per_capita  primary_energy_consumption
# 0                  0.064            484.347                       7.871
# 1                  0.059            386.491                       6.596
# 2                  0.055            368.900                       6.553
# 3                  0.051            341.219                       6.296
# 4                  0.049            321.279                       6.156
# ...                  ...                ...                         ...
# 4915               0.247           2603.889                      39.765
# 4916               0.197           2163.075                      33.586
# 4917               0.236           2382.443                      37.636
# 4918               0.210           3633.079                      58.380
# 4919               0.206           3181.371                      51.986
#
# [4920 rows x 14 columns]

# %%
# Drop iso_code columns as no longer relevant
df_merged = df_merged.drop(columns=['iso_code'], errors='ignore')
df_merged
# Out:
#           country  region  year  population          gdp    co2  \
# 0     Afghanistan    Asia  1994    16250799   7919856640  1.454
# 1     Afghanistan    Asia  1995    17065836  12307525632  1.417
# 2     Afghanistan    Asia  1996    17763265  12070125568  1.370
# 3     Afghanistan    Asia  1997    18452100  11850753024  1.304
# 4     Afghanistan    Asia  1998    19159996  11692171264  1.279
# ...           ...     ...   ...         ...          ...    ...
# 4915     Zimbabwe  Africa  2019    15271377  25146417152 10.263
# 4916     Zimbabwe  Africa  2020    15526888  23178706944  8.495
# 4917     Zimbabwe  Africa  2021    15797220  25140088832 10.204
# 4918     Zimbabwe  Africa  2022    16069061  25901586432 10.425
# 4919     Zimbabwe  Africa  2023    16340829  23049979833 11.164
#
#       co2_per_capita  cumulative_co2  cumulative_oil_co2  oil_co2  \
# 0              0.089          64.941              33.346    1.032
# 1              0.083          66.358              34.357    1.011
# 2              0.077          67.728              35.343    0.986
# 3              0.071          69.032              36.292    0.949
# 4              0.067          70.311              37.234    0.942
# ...              ...             ...                 ...      ...
# 4915           0.672         774.802             144.767    3.778
# 4916           0.547         783.296             147.830    3.063
# 4917           0.646         793.500             151.565    3.735
# 4918           0.649         803.925             154.944    3.379
# 4919           0.683         815.089             158.306    3.362
#
#       oil_co2_per_capita  energy_per_capita  primary_energy_consumption
# 0                  0.064            484.347                       7.871
# 1                  0.059            386.491                       6.596
# 2                  0.055            368.900                       6.553
# 3                  0.051            341.219                       6.296
# 4                  0.049            321.279                       6.156
# ...                  ...                ...                         ...
# 4915               0.247           2603.889                      39.765
# 4916               0.197           2163.075                      33.586
# 4917               0.236           2382.443                      37.636
# 4918               0.210           3633.079                      58.380
# 4919               0.206           3181.371                      51.986
#
# [4920 rows x 13 columns]
